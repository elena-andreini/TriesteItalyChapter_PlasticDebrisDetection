# %%
# !git clone -b master https://github.com/elena-andreini/TriesteItalyChapter_PlasticDebrisDetection.git
# Out:
# Cloning into 'TriesteItalyChapter_PlasticDebrisDetection'...
# remote: Enumerating objects: 1801, done.
# remote: Counting objects: 100% (294/294), done.
# remote: Compressing objects: 100% (128/128), done.
# remote: Total 1801 (delta 207), reused 217 (delta 162), pack-reused 1507 (from 2)
# Receiving objects: 100% (1801/1801), 249.78 MiB | 34.83 MiB/s, done.
# Resolving deltas: 100% (757/757), done.

# %%
# %%capture
# for simplicity, kaggle already have everything you need installed, except for rasterio
# %pip install rasterio

# %%
# !git clone -b master https://github.com/elena-andreini/TriesteItalyChapter_PlasticDebrisDetection.git
# %cd TriesteItalyChapter_PlasticDebrisDetection
# Out:
# Cloning into 'TriesteItalyChapter_PlasticDebrisDetection'...
# remote: Enumerating objects: 1817, done.
# remote: Counting objects: 100% (311/311), done.
# remote: Compressing objects: 100% (140/140), done.
# remote: Total 1817 (delta 217), reused 228 (delta 167), pack-reused 1506 (from 2)
# Receiving objects: 100% (1817/1817), 249.78 MiB | 40.03 MiB/s, done.
# Resolving deltas: 100% (767/767), done.
# /kaggle/working/TriesteItalyChapter_PlasticDebrisDetection/TriesteItalyChapter_PlasticDebrisDetection/TriesteItalyChapter_PlasticDebrisDetection/TriesteItalyChapter_PlasticDebrisDetection

# %%
# !python train.py
# Out:
# split files loaded
# data loaders initiated
# dataset sample loading benchmark: <torch.utils.benchmark.utils.common.Measurement object at 0x7ca4efd20750>
# dataset[42]
#   26.13 ms
#   1 measurement, 100 runs , 1 thread
# class distribution [0.96271333 0.03728667]
# models/checkpoints/best_model.pth ['__pycache__', 'resattenunet.py', '__init__.py', 'checkpoints']
# epoch 1/60: 100%|█| 120/120 [03:05<00:00,  1.55s/it, batch_time=0.0858, loss=0.1
# epoch time: 185.590470943
# ########### Validation Set Evaluation : #############
# accuracy: 0.8493914972182797
#
# plastic debris metrics
# 	 precision: 0.22637743539763197
# 	 recall: 0.9643157571146096
# 	 f1: 0.35338467902025744
# 	 iou: 0.22303238182695134
#
# background metrics
# 	 precision: 0.9973125682913334
# 	 recall: 0.8493914972182797
# 	 f1: 0.9155054788030682
# 	 iou: 0.8474999722747313
# ########################################
# ...
