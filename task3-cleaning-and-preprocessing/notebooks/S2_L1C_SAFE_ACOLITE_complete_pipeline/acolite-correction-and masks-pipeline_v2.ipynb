# %%
! git clone https://github.com/acolite/acolite.git
# Out:
# Cloning into 'acolite'...
# remote: Enumerating objects: 13006, done.
# remote: Counting objects: 100% (2109/2109), done.
# remote: Compressing objects: 100% (330/330), done.
# remote: Total 13006 (delta 1952), reused 1840 (delta 1778), pack-reused 10897 (from 3)
# Receiving objects: 100% (13006/13006), 711.70 MiB | 41.03 MiB/s, done.
# Resolving deltas: 100% (8319/8319), done.

# %%
# %%capture
! pip install rasterio
! pip install pyresample
! pip install netCDF4
# !pip install dvc dagshub

# %%
import os
import sys
import rasterio
from rasterio.windows import Window
from rasterio.windows import from_bounds
from rasterio.enums import Resampling
from rasterio.transform import Affine
import shutil
import numpy as np
import tempfile
import shutil
from pyproj import Transformer
import gdown
import dask.dataframe as dd
import glob
from tqdm import tqdm
import cv2
import dagshub
from dagshub.upload import Repo

# %%
from dagshub.auth import add_app_token
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
dagshub_username = user_secrets.get_secret("DAGSHUB_USERNAME")
dagshub_token = user_secrets.get_secret("DAGSHUB_TOKEN")
add_app_token(dagshub_token)

# %%
ACOLITE_PATH = "./acolite"
sys.path.append(ACOLITE_PATH)
# Import acolite_run
from acolite.acolite.acolite_run import acolite_run

# %%
def get_utm_limit(utm_x, utm_y,utm_crs, box_meters, pixel_size=10):
    """Compute WGS84 limit from UTM center for box_meters x box_meters."""
    #utm_crs = "EPSG:32631"  # UTM 31N
    wgs84_crs = "EPSG:4326"
    utm_to_wgs = Transformer.from_crs(utm_crs, wgs84_crs, always_xy=True)
    
    half_box = box_meters / 2
    box_left = utm_x - half_box
    box_right = utm_x + half_box
    box_bottom = utm_y - half_box
    box_top = utm_y + half_box
    
    lon_min, lat_min = utm_to_wgs.transform(box_left, box_bottom)
    lon_max, lat_max = utm_to_wgs.transform(box_right, box_top)
    limit = [lat_min, lon_min, lat_max, lon_max]
    
    print(f"UTM box: left={box_left:.1f}, bottom={box_bottom:.1f}, right={box_right:.1f}, top={box_top:.1f}")
    print(f"WGS84 limit: {limit}")
    return limit, (box_left, box_bottom, box_right, box_top)

# %%
# def crop_to_exact_size(input_file, output_file, target_width=256, target_height=256, annot_utm_x=None, annot_utm_y=None):
#     with rasterio.open(input_file) as src:
#         width, height = src.width, src.height
#         print(f"Input shape: {width}x{height}")
#         res = src.res[0]
#         if annot_utm_x is not None and annot_utm_y is not None:
#             x_offset = int((annot_utm_x - src.bounds.left) / res - target_width / 2)
#             y_offset = int((src.bounds.top - annot_utm_y) / res - target_height / 2)
#         else:
#             x_offset = (width - target_width) // 2
#             y_offset = (height - target_height) // 2
#         x_offset = max(0, min(x_offset, width - target_width))
#         y_offset = max(0, min(y_offset, height - target_height))
#         window = Window(x_offset, y_offset, target_width, target_height)
#         data = src.read(window=window)
#         transform = src.window_transform(window)
#         profile = src.profile
#         profile.update(width=target_width, height=target_height, transform=transform)
#         with rasterio.open(output_file, 'w', **profile) as dst:
#             dst.write(data)
#         print(f"Cropped to: {target_width}x{target_height}")
#         print(f"Output UTM bounds: left={transform[2]:.1f}, bottom={transform[5]-target_height*res:.1f}, "
#               f"right={transform[2]+target_width*res:.1f}, top={transform[5]:.1f}")
#         return transform[2], transform[5]

# %%
! ls /kaggle/input/litter-windrows-batch-cala
safe_files_dir ='/kaggle/input/litter-windrows-batch-cala'
# Out:
# S2A_MSIL1C_20150814T094006_N0500_R036_T33SXC_20231010T034522
# S2A_MSIL1C_20150923T094016_N0500_R036_T33SXC_20231028T021114
# S2A_MSIL1C_20151115T095252_N0500_R079_T33SXC_20231021T074400
# S2A_MSIL1C_20161126T094332_N0500_R036_T33SXC_20231025T160709
# S2A_MSIL1C_20181007T094031_N0500_R036_T33SXC_20230727T233522
# S2A_MSIL1C_20181010T095031_N0500_R079_T33SXC_20230729T115020
# S2A_MSIL1C_20181017T094011_N0500_R036_T33SXC_20230729T163213
# S2A_MSIL1C_20181027T094101_N0500_R036_T33SXC_20230817T053449
# S2A_MSIL1C_20181106T094201_N0500_R036_T33SXC_20230727T210154
# S2A_MSIL1C_20181109T095221_N0500_R079_T33SXC_20230813T172922
# S2A_MSIL1C_20200110T094351_N0500_R036_T33SXC_20230603T093842
# S2A_MSIL1C_20200409T094031_N0500_R036_T33SXC_20230426T035222
# S2A_MSIL1C_20201228T095421_N0500_R079_T33SXC_20230401T085523

# %%
def get_dataset_tiles(safe_files_dir):
    tiles = os.listdir(safe_files_dir)
    tiles = [str(t)+'.SAFE' for t in tiles]
    return tiles

# %%
# List the tiles in the dataset
#safe_files_dir = '/kaggle/input/litter-windrows-batch-cala'
# tiles = os.listdir(safe_files_dir)
# tiles = [str(t)+'.SAFE' for t in tiles]
tiles = get_dataset_tiles(safe_files_dir)
tiles
# Out:
# ['S2A_MSIL1C_20201228T095421_N0500_R079_T33SXC_20230401T085523.SAFE',
#  'S2A_MSIL1C_20151115T095252_N0500_R079_T33SXC_20231021T074400.SAFE',
#  'S2A_MSIL1C_20181027T094101_N0500_R036_T33SXC_20230817T053449.SAFE',
#  'S2A_MSIL1C_20200409T094031_N0500_R036_T33SXC_20230426T035222.SAFE',
#  'S2A_MSIL1C_20181109T095221_N0500_R079_T33SXC_20230813T172922.SAFE',
#  'S2A_MSIL1C_20181017T094011_N0500_R036_T33SXC_20230729T163213.SAFE',
#  'S2A_MSIL1C_20150814T094006_N0500_R036_T33SXC_20231010T034522.SAFE',
#  'S2A_MSIL1C_20181007T094031_N0500_R036_T33SXC_20230727T233522.SAFE',
#  'S2A_MSIL1C_20150923T094016_N0500_R036_T33SXC_20231028T021114.SAFE',
#  'S2A_MSIL1C_20161126T094332_N0500_R036_T33SXC_20231025T160709.SAFE',
#  'S2A_MSIL1C_20200110T094351_N0500_R036_T33SXC_20230603T093842.SAFE',
#  'S2A_MSIL1C_20181010T095031_N0500_R079_T33SXC_20230729T115020.SAFE',
#  'S2A_MSIL1C_20181106T094201_N0500_R036_T33SXC_20230727T210154.SAFE']

# %%
# def get_utm_zone(longitude):
#     return int((longitude + 180) / 6) + 1

# longitude = 15.65  # Example for Calabria
# utm_zone = get_utm_zone(longitude)
# print(f"UTM Zone: {utm_zone}N")  # Outputs UTM Zone for Northern Hemisphere

# from pyproj import Transformer

# lat, lon = 38.5, 16.5  # Example for Calabria
# utm_zone = get_utm_zone(lon)
# epsg_code = f"EPSG:{32600 + utm_zone}"  # UTM Northern Hemisphere Code

# transformer = Transformer.from_crs("EPSG:4326", epsg_code, always_xy=True)
# utm_x, utm_y = transformer.transform(lon, lat)

# print(f"UTM Coordinates: X={utm_x}, Y={utm_y}, Zone={utm_zone}N")

# %%
def extract_crs_and_bounds(safe_file):
    #granule_path = os.path.join(os.path.join(safe_files_dir, tiles[0]), tiles[0]+'.SAFE/GRANULE/')
    granule_path = os.path.join(safe_file, 'GRANULE/')
    #print(granule_path)
    granule_subdirs = os.listdir(granule_path)  
    img_data_path = os.path.join(granule_path, os.path.join(granule_subdirs[0]),'IMG_DATA/')
    jpg2_files = os.listdir(img_data_path)
    #print('jpg2_files')
    #print(jpg2_files)
    B02_files = [f  for f in jpg2_files if f.endswith('B02.jp2')]
    #print('B02_files')
    #print(B02_files)
    band_path = os.path.join(img_data_path, B02_files[0])
    print(band_path)
    with rasterio.open(band_path) as src:
        print(f"CRS: {src.crs}")  # Should be EPSG:32631
        print(f"Bounds: {src.bounds}")  # Exact UTM coordinates
        data = src.read(1)
        print(f"B02 Valid Pixels: {np.sum(data > 0)} / {data.size}")
    return src.crs, src.bounds, src.transform, src.res

# %%
def get_all_tiles(files):
    """
    Given the list of the parquet annotation file, builds the list of all the 
    annotated tiles.
    """
    df = None
    # Process 10 files per batch
    batch_size = 10
    tiles = []
    for i in range(0, len(files), batch_size):
        batch_files = files[i:i + batch_size]
        
        # Read batch with Dask (lazy loading)
        ddf = dd.read_parquet(batch_files, engine='pyarrow')
        
        # Compute to pandas (triggers parallel read)
        batch_df = ddf.compute()  # Now contains data from 10 files
        tiles.append(batch_df['s2_product'].unique())
       
        print(f"Batch {i//batch_size + 1}: {len(batch_df)} rows (from {len(batch_files)} files)")
    
    tiles = np.unique(np.hstack(tiles))
    tiles = [t.decode('utf-8') for t in tiles]
    return tiles

# %%
def find_jp2_ref_file(safe_file):
    granule_path = os.path.join(safe_file, 'GRANULE/')
    granule_subdirs = os.listdir(granule_path)  
    img_data_path = os.path.join(granule_path, os.path.join(granule_subdirs[0]),'IMG_DATA/')
    jpg2_files = os.listdir(img_data_path)
    B02_files = [f  for f in jpg2_files if f.endswith('B02.jp2')]
    if len(B02_files) == 0:
        raise ValueError(f'No B2 band jpg2 file retrieve in the safe file {safe_file}')
    else :
        return os.path.join(img_data_path, B02_files[0])
        
def check_for_invalid_data(file_path, bbox):
    with rasterio.open(file_path) as src:
        # Read the window
        window = src.window(*bbox)
        data = src.read(1, window=window)
    
    # Sentinel-2 often uses 0 for invalid pixels
    invalid_mask = (data == 0)
    
    # Or sometimes very high values (like 65535 for uint16)
    if data.dtype == np.uint16:
        invalid_mask = invalid_mask | (data == 65535)
    
    has_invalid = invalid_mask.any()
    
    if has_invalid:
        invalid_count = invalid_mask.sum()
        print(f"Found {invalid_count} invalid pixels in the bounding box")
    else:
        print("No invalid pixels found in the bounding box")
    return has_invalid

def generate_tile_regions(safe_file_path):
    """
    Returns regions splitting the tile image
    in the form of (xmin, ymin, xmax, ymax)
    """
    w = 10980
    h = 10980
    stepx = 2700
    stepy = 2700
    sx = 3000
    sy = 3000
    regions = []
    for i in range(4):
        for j in range(4):
            regions.append((i*stepx, j*stepy, min(w, i*stepx + sx), min(h, j*stepy + sy)))
    ref_file = find_jp2_ref_file(safe_file_path)
    filtered_regions = []
   
    for r in regions :
        invalid = check_for_invalid_data(ref_file, r)
        if not invalid:
            filtered_regions.append(r)
    regions = {i : r for i, r in enumerate(filtered_regions)}
    return regions

def assign_patches(tile_regions, patches):
    splitted_regions = {}
    for p in patches: 
        for idr, r in tile_regions.items():
            inside = p[0] >= r[0] and p[1] >= r[1] and p[2] <= r[2] and p[3] <= r[3]
            if inside:
                if idr  not in splitted_regions:
                    splitted_regions[idr] = [p]
                else :
                    splitted_regions[idr].append(p)
                break
    return splitted_regions

# %%
def generate_tile_mask(tile_df):
    """
    Generate mask for the whole tile.
    Based on dhia's code.
    Not filtering filaments by box_dims size at the moment
    """
    mask = np.zeros((10980, 10980))
    pixels = 0
    #pb = tqdm(tile_df[tile_df["box_dims"] == 3].iterrows())
    pb = tqdm(tile_df.iterrows())
    for index, row in pb:
        x, y = row["pixel_x"], row["pixel_y"]
        if not np.isnan(x) and not np.isnan(y):
            pixels += 1
            x, y = int(x), int(y)
            mask[x, y] = 1
    return mask, pixels
    
def find_subregions_efficient(binary_image, subregion_size, threshold):
    """
    Finds regions with debris pixels in the whole tile annotation mask.
    Using integral images for large binary images.
    """
    h, w = subregion_size
    img_h, img_w = binary_image.shape
    print(f'input maks shape : {binary_image.shape}')
    # Convert to binary and create integral image
    binary = (binary_image == 1).astype(np.uint8)
    integral = cv2.integral(binary)
    
    subregions = []
    covered = np.zeros_like(binary, dtype=bool)
    
    for y in range(0, img_h - h + 1, h):
        for x in range(0, img_w - w + 1, w):
            #if covered[y:y+h, x:x+w].any():
            #    continue
                
            # Calculate sum using integral image
            total = integral[y+h, x+w] - integral[y, x+w] - integral[y+h, x] + integral[y, x]
            white_fraction = total / (h * w)
            #print(f'white_fraction {white_fraction}')
            if total > threshold:
                subregions.append((x, y,  x + w,  y + h, total))
                covered[y:y+h, x:x+w] = True
                
    return subregions

def minimal_1024_cover(small_regions):
    """
    This function could be used to find larger regions around patches
    for ACOLITE application.
    DSF algorithm could be not completely reliable applied to regions of 2560x2560 m unless
    they are very homogeneous
    """
    # Converti le coordinate in celle della griglia 256×256
    cells = set((x // 1024, y // 1024) for (y, x, _, _,_) in small_regions)
    if not cells:
        return []
    large_regions = set()
    for (i, j) in cells:
        large_i = i * 1024
        large_j = j * 1024
        large_regions.add((large_i, large_j))
    return large_regions


def upload_to_drive(file_path, drive_folder_id):
    """Upload file to Google Drive."""
    output = gdown.upload(file_path, parent_id=drive_folder_id, quiet=False)
    print(f"Uploaded {file_path} to Drive folder {drive_folder_id}")
    os.remove(file_path)  # Clear Kaggle disk

# %%
def build_tile_df(target, files):
    """
    Retrieves all annotations for a given target tile.
    """
    df = None
    # Process 10 files per batch
    batch_size = 10
    tg_id_1 = target.split('_')[2]
    tg_id_2 = '_'.join(target.split('_')[4:6])
    for i in range(0, len(files), batch_size):
        batch_files = files[i:i + batch_size]
        
        # Read batch with Dask (lazy loading)
        ddf = dd.read_parquet(batch_files, engine='pyarrow')
        
        # Compute to pandas (triggers parallel read)
        batch_df = ddf.compute()  # Now contains data from 10 files
        batch_df["s2_product"] = batch_df["s2_product"].str.decode('utf-8')
        batch_df = batch_df[batch_df["s2_product"].str.contains(tg_id_1) & batch_df["s2_product"].str.contains(tg_id_2)]
        if not batch_df.empty:
            if df is None:
                df = batch_df.copy()
            else:
                df = pd.concat([df, batch_df], ignore_index=True)
        print(f"Batch {i//batch_size + 1}: {len(batch_df)} rows (from {len(batch_files)} files)")
    return df

# %%
def get_relative_path(target_path, start_path):
    """
    Returns the relative path from start_path to target_path
    """
    return os.path.relpath(target_path, start_path)


def get_all_files_recursive(directory):
    file_paths = []
    for root, dirs, files in os.walk(directory):
        #print(files)
        for file in files:
            full_path = os.path.abspath(os.path.join(root, file))
            if os.path.isfile(full_path):  # Check to ensure it's a file
                file_paths.append(full_path)
    return file_paths

def upload_to_dagshub(root_folder, src_folder, dst_folder, batch_id, dagshub_token):
    """
    dst_folder: Must have the format './dest_folder',
    where dst_folder is the destination folder for the images
    relative to the root of the repository.
    
    root_folder: The relative path of src_folder with respect to root_folder
    will determine the position of the uploaded file relative to the root
    of the repository.
    """

    # Defining the Repo & directory
    add_app_token(dagshub_token)
    repo = Repo("elena-andreini", "TriesteItalyChapter_PlasticDebrisDetection")
    ds = repo.directory(dst_folder)
    files = get_all_files_recursive(src_folder)
    print(f'uploading files {files}')
    rel_files_paths = [get_relative_path(f, src_folder) for f in files]
    print(f'relative files {rel_files_paths}')

    for i in rel_files_paths:
      ds.add(file=os.path.join(src_folder, i), path=f'./{i}')
    
    # Commit the changes
    ds.commit(f'Adding batch {batch_id}  to {dst_folder} folder', versioning='dvc')
    print(f'Uploaded batch {batch_id}')

# %%
# Define settings form map-mapper paper
settings = {
    # Ensure TIFF export
    'l2r_export_geotiff': True,  
    # delete .nc once made to geotiff
    'l1r_delete_netcdf' : True,
    'l2w_delete_netcdf' : True,
    'verbosity': 5,  # Detailed logging
    's2_target_res': 10,  # 10m resolution
    'resampling_method': 'nearest' , # Set to nearest neighbor
    'atmospheric_correction_method': 'dark_spectrum',
    'dsf_exclude_bands' : ['B9', 'B10'],
    # resolves issue with none type see this thread - https://odnature.naturalsciences.be/remsem/acolite-forum/viewtopic.php?t=319
    'geometry_type' : 'grids',
    #masking
    'l2w_mask' : False,
    #sunglint
    'glint_correction' : True,
    'dsf_residual_glint_correction' : True,
    'dsf_residual_glint_correction_method' : 'alternative', # index error occuring with default
    'dsf_residual_glint_wave_range' : [1500,2400],
    'glint_force_band' : None,
    'glint_mask_rhos_wave' : 1600,
    'glint_mask_rhos_threshold' : 0.11,
    'reproject' : False
}

# %%
def validate_image(image):
    # Define invalid values (NaN, Inf, or negative)
    invalid_mask = np.isnan(image) | np.isinf(image) | (image < 0)
    total_pixels = image.size
    invalid_count = invalid_mask.sum()
    invalid_percentage = (invalid_count / total_pixels) * 100
    print(f"Percentage of invalid values (NaN, Inf, negative) across all bands: {invalid_percentage:.2f}%")
    if invalid_percentage > 10:
        print('skipping region, too many invalid pixels ')
        return False
    else :
        return True

# %%
#### Stacking 


def stack_bands(acolite_output_dir, stacked_dir, tile):
    # Mapping wawelength to band names
    wl_to_band  ={
        443 : 'B1',
        492 : 'B2',
        560 : 'B3',
        665 : 'B4',
        704 : 'B5',
        740 : 'B6',
        783 : 'B7',
        833 : 'B8',
        865 : 'B8A',
        1614 : 'B11',
        2202 : 'B12'
    }
    rhos_files = [f for f in os.listdir(acolite_output_dir) if 'rhos' in f and '.tif' in f]
    rhos_files = sorted(rhos_files, key=lambda x: int(x.split('_')[-1][:-4]))
    band_files = [(wl_to_band[int(f.split('_')[-1][:-4])], f) for i,f in enumerate(rhos_files) ]

    # Verify all files exist
    for band, filename in band_files:
        if not os.path.exists(os.path.join(acolite_output_dir, filename)):
            raise FileNotFoundError(f"Missing file: {filename}")

    # Reference band (use B4 for metadata, since all bands are 10m)
    reference_band = 'B4'
    reference_file = os.path.join(acolite_output_dir, [f for b, f in band_files if b == reference_band][0])

    # Open the reference GeoTIFF to get metadata
    with rasterio.open(reference_file) as ref:
        ref_profile = ref.profile
        ref_transform = ref.transform
        ref_crs = ref.crs
        ref_width = ref.width
        ref_height = ref.height
        ref_resolution = ref.res  # Should be (10.0, 10.0)

    # Initialize an array to store all bands
    stacked_data = np.zeros((len(band_files), ref_height, ref_width), dtype=np.float32)
    
    # Read each band (no resampling needed, all are 10m)
    for i, (band, filename) in enumerate(band_files):
        file_path = os.path.join(acolite_output_dir, filename)
        with rasterio.open(file_path) as src:
            # Verify resolution matches
            if src.res != ref_resolution:
                raise ValueError(f"Resolution mismatch in {filename}: expected {ref_resolution}, got {src.res}")
            # Verify dimensions match
            if src.width != ref_width or src.height != ref_height:
                raise ValueError(f"Dimensions mismatch in {filename}: expected {ref_width}x{ref_height}, got {src.width}x{src.height}")
            # Read the band
            data = src.read(1, out_dtype=np.float32)  # Single band, float32
            stacked_data[i] = data

    # Update the profile for the stacked GeoTIFF
    stacked_profile = ref_profile.copy()
    stacked_profile.update({
        'count': len(band_files),  # 11 bands
        'dtype': np.float32,  # For reflectance
        'transform': ref_transform,
        'crs': ref_crs,
        'width': ref_width,
        'height': ref_height,
        'nodata': -999  # Optional: Set nodata value (adjust if ACOLITE uses NaN)
    })
    # Determine patch name similar to MARIDA : S2_DATE_TILE_REGION in folder S2_DATE_TILE
    stacked_tif_fname =  'S2_'+('_'.join(tile.split('_')[2:-3]))+'_stacked.tiff'
    stacked_tif = os.path.join(stacked_dir, stacked_tif_fname)
    # Save the stacked GeoTIFF
    with rasterio.open(stacked_tif, 'w', **stacked_profile) as dst:
        dst.write(stacked_data)
        # Set band descriptions in the usual order
        for i, (band, _) in enumerate(band_files, 1):
            dst.set_band_description(i, band)
    
    print(f"Stacked GeoTIFF saved to: {stacked_tif}")

    # Verify the stacked GeoTIFF
    with rasterio.open(stacked_tif) as stacked:
        print(f"Stacked GeoTIFF:")
        print(f"Bounds: {stacked.bounds}")
        print(f"Dimensions: {stacked.width} columns, {stacked.height} rows")
        print(f"Resolution: {stacked.res}")
        print(f"CRS: {stacked.crs}")
        print(f"Number of bands: {stacked.count}")
        print(f"Band descriptions: {stacked.descriptions}")
    valid = validate_image(stacked_data)
    return stacked_tif, valid

# %%
######## Cropping


# Paths to the original GeoTIFF, stacked GeoTIFF, and output
def crop_stacked_file(stacked_tif, cropped_tif, utm_box, crs, tile_res):
    
    # Computing metadata for the original patch (before ACOLITE correction)
    
    initial_bounds = utm_box  
    original_width = 256
    original_height = 256
    original_transform = Affine.translation(utm_box[0], utm_box[3]) * Affine.scale(10.0, -10.0)
    original_crs = crs
    original_resolution = tile_res

    # Open the stacked GeoTIFF and crop to initial bounds
    with rasterio.open(stacked_tif) as src:
        # Define a window based on the initial bounds
        window = from_bounds(*initial_bounds, transform=src.transform)
        
        # Read the data, matching original dimensions
        window_data = src.read(
            window=window,
            out_shape=(src.count, original_height, original_width),
            resampling=Resampling.nearest  # Nearest neighbor to avoid interpolation
        )
        
        # Get band descriptions to preserve metadata
        band_descriptions = src.descriptions
        
        # Update the transform to match the original GeoTIFF
        window_transform = original_transform
        
        # Update the profile with new metadata
        profile = src.profile
        profile.update({
            'width': original_width,
            'height': original_height,
            'transform': window_transform,
            'crs': original_crs
        })
        
        # Create a new GeoTIFF with the cropped data
        with rasterio.open(cropped_tif, 'w', **profile) as dst:
            dst.write(window_data)
            # Preserve band descriptions (e.g., B1, B2, ...)
            for i, desc in enumerate(band_descriptions, 1):
                if desc:  # Only set if description exists
                    dst.set_band_description(i, desc)
    
    print(f"Cropped GeoTIFF saved to: {cropped_tif}")

    # Verify the cropped GeoTIFF
    with rasterio.open(cropped_tif) as cropped:
        print(f"Cropped GeoTIFF:")
        print(f"Bounds: {cropped.bounds}")
        print(f"Dimensions: {cropped.width} columns, {cropped.height} rows")
        print(f"Resolution: {cropped.res}")
        print(f"CRS: {cropped.crs}")
        print(f"Number of bands: {cropped.count}")
        print(f"Band descriptions: {cropped.descriptions}")

# %%
##### Run if you want to extract all tiles from the LW annotation file
#%%time
#all_tiles = get_all_tiles(annotations_files)

# %%
def process_tile(target, safe_files_dir, annotations_files, output_dir, remote_dataset_location = './LWC_DataSet/test_data', batch_id='', clean_patches = True, dagshub_token=''):
    acolite_output_dir = os.path.join(output_dir, 'acolite_output/')
    stacked_dir = os.path.join(output_dir, 'stacked/')
    final_dir = os.path.join(output_dir, 'patches/')
    os.makedirs(acolite_output_dir, exist_ok=True)
    os.makedirs(stacked_dir, exist_ok=True)
    if clean_patches : 
        shutil.rmtree(acolite_output_dir, ignore_errors=True)
    os.makedirs(final_dir, exist_ok=True)
    print(f'building annotations dataframe for tile {target}')
    tile_df = build_tile_df(target, annotations_files)
    mask, debris_pixels_count = generate_tile_mask(tile_df)
    print(f'tile mask shape {mask.shape}')
    if debris_pixels_count == 0:
        print(f'no valid debris pixels in tile {target}')
        return False
    patches = find_subregions_efficient(mask, (256, 256), 0)
    print(f'patches with marine debris : {patches}')
    target_file_path = os.path.join(os.path.join(safe_files_dir, target[:-5]), target)
    crs, bounds, tile_transform, tile_res = extract_crs_and_bounds(target_file_path)       
    print(f'crs : {crs}')
    print(f'bounds : {bounds}')
    res = tile_res[0] #sentinel 2 max resolution
    tile_regions = generate_tile_regions(target_file_path)
    patches_per_region = assign_patches(tile_regions, patches)
    print(f'patches per region {patches_per_region}')
    for i, ppr in patches_per_region.items(): #iterates over regions containing patches
        shutil.rmtree(stacked_dir, ignore_errors=True)
        os.makedirs(stacked_dir, exist_ok=True)
        current_region = tile_regions[i]
        current_center = ((current_region[0] + current_region[2])/2 * res + bounds.left,
        (current_region[1] + current_region[3])/2 * res + bounds.bottom)
        #subregion_centers = [((int(p[1] + p[3])/2) * res + bounds.left, int((p[0] + p[2])/2) * res + bounds.bottom) for p in patches]
        print(f'region center : {current_center}')
        #subregion_size = (256 * res, 256 * res)
        current_region_size = ((current_region[2] - current_region[0]) * res, 
                               (current_region[3] - current_region[1]) * res )
        try:
            # Check disk usage
            print("Disk usage before run:")
            # !du -sh /kaggle/input/*
            # !df -h /kaggle/tmp /kaggle/working
        
            # Clear output directory
            shutil.rmtree(acolite_output_dir, ignore_errors=True)
            os.makedirs(acolite_output_dir, exist_ok=True)


        # Process each subregion
        #for i, (subregion_utm_x, subregion_utm_y) in enumerate(subregion_centers):
            # Clear output directory
            subregion_utm_x, subregion_utm_y = current_center
            print(f'Cleaning previous acolite output')
            shutil.rmtree(acolite_output_dir, ignore_errors=True)
            os.makedirs(acolite_output_dir, exist_ok=True)
            print(f"\nProcessing subregion {i+1}/{len(tile_regions)} centered at UTM ({subregion_utm_x}, {subregion_utm_y})")
    
            # Compute UTM-based limit
            limit, utm_box = get_utm_limit(subregion_utm_x, subregion_utm_y, crs, current_region_size[0]) #subregion_size[0])
            print(f'setting limit : {limit}')
            settings['limit'] = limit
            print(f"Settings for subregion {i+1}: {settings}")
            output_files = acolite_run(settings=settings, inputfile=target_file_path, output=acolite_output_dir)
            print(f"Generated output files {output_files}")
            print('stacking bands')
            stacked_tiff, valid = stack_bands(acolite_output_dir, stacked_dir, target)
            if not valid : 
                print(f'skipping region {current_region} : too many invalid pixels')
                continue
            patch_dir =  os.path.join(final_dir, '_'.join((stacked_tiff.split('/')[-1]).split('_')[:-1]))# '_'.join(stacked_tiff.split('_')[:-1])
            print(f'patch dir {patch_dir}')
            for p in ppr:
                print(f'cropping  patch {p}')
                patch_utm_bound = (p[0] * res + bounds.left, p[1] * res + bounds.bottom,
                                   p[2] * res + bounds.left, p[3] * res + bounds.bottom)
                patch_name_prefix = patch_dir.split('/')[-1]
                patch_name = f'{patch_name_prefix}_{int(patch_utm_bound[0])}_{int(patch_utm_bound[1])}.tiff'
                patch_pathname = os.path.join(patch_dir, patch_name)
                os.makedirs(patch_dir, exist_ok=True)
                print(f'patch pathname {patch_pathname}')
                crop_stacked_file(stacked_tiff, os.path.join(patch_dir, patch_pathname), patch_utm_bound, crs, tile_res)
                patch_mask = mask[p[1] : p[3], p[0] : p[2]]
                print(f'patch mask shape {patch_mask.shape}')
                try:
                    cv2.imwrite(os.path.join(patch_dir, f'{patch_pathname[:-4]}_cl.tif'), patch_mask)
                except Exception as e:
                    print(f"Error writing mask: {e}")
            # Insert Sanity Check for ACOLITE output ? 
            
            # Upload to DagsHub
            if dagshub_token:
                upload_to_dagshub(output_dir, final_dir, remote_dataset_location, batch_id, dagshub_token)
    
    

            # Final disk usage
            print("\nDisk usage after run:")
            ! du -sh /kaggle/input/*
            # !df -h /kaggle/tmp /kaggle/working
      
    
        except Exception as e:
            print(f"Exception captured: {e}")

# %%
### Setting the directory of the annotations file split and converted to parquet format
parquet_annotations_dir = '/kaggle/input/lw-parquet/kaggle/working'
annotations_files = [os.path.join(parquet_annotations_dir, f) for f in os.listdir(parquet_annotations_dir)]

# %%
def process_batch(tiles, safe_files_dir, annotations_files, batch_id='', dagshub_token=''):
    """
    tiles :  list of tiles (SAFE files) in batch batch_id
    """
    clean_patches = len(dagshub_token) != 0
    for target in tiles:
        process_tile(target, safe_files_dir, annotations_files, '/kaggle/working', batch_id, clean_patches =clean_patches, dagshub_token=dagshub_token)

# %%
process_batch([tiles[7]],safe_files_dir, annotations_files,  batch_id='', dagshub_token='')
# Out:
# building annotations dataframe for tile S2A_MSIL1C_20181007T094031_N0500_R036_T33SXC_20230727T233522.SAFE
# Batch 1: 0 rows (from 10 files)
# Batch 2: 0 rows (from 10 files)
# Batch 3: 0 rows (from 10 files)
# Batch 4: 0 rows (from 10 files)
# Batch 5: 399828 rows (from 10 files)
# Batch 6: 0 rows (from 10 files)
# Batch 7: 0 rows (from 10 files)
# Batch 8: 0 rows (from 10 files)
# Batch 9: 0 rows (from 10 files)
# Batch 10: 0 rows (from 10 files)
# Batch 11: 0 rows (from 10 files)
# Batch 12: 0 rows (from 10 files)
# Batch 13: 0 rows (from 10 files)
# Batch 14: 0 rows (from 10 files)
# Batch 15: 0 rows (from 8 files)
# 399828it [00:19, 20512.64it/s]
# tile mask shape (10980, 10980)
# input maks shape : (10980, 10980)
# patches with marine debris : [(8448, 256, 8704, 512, 206), (8704, 256, 8960, 512, 156), (8448, 512, 8704, 768, 3), (4096, 768, 4352, 1024, 15), (4096, 1792, 4352, 2048, 163), (4096, 2048, 4352, 2304, 106), (4096, 2304, 4352, 2560, 73), (3840, 2560, 4096, 2816, 125), (4096, 2560, 4352, 2816, 41), (4352, 2560, 4608, 2816, 64), (3584, 2816, 3840, 3072, 195), (3840, 2816, 4096, 3072, 109), (3584, 3072, 3840, 3328, 41), (3840, 3072, 4096, 3328, 3), (3584, 3328, 3840, 3584, 16), (3584, 3584, 3840, 3840, 109), (3840, 3584, 4096, 3840, 61), (4352, 3584, 4608, 3840, 92), (4608, 3584, 4864, 3840, 247), (3840, 3840, 4096, 4096, 57), (4096, 3840, 4352, 4096, 6), (4352, 3840, 4608, 4096, 156), (4608, 3840, 4864, 4096, 9), (5376, 3840, 5632, 4096, 86), (6400, 3840, 6656, 4096, 116), (4352, 4096, 4608, 4352, 67), (4608, 4096, 4864, 4352, 92), (5376, 4096, 5632, 4352, 241), (5632, 4096, 5888, 4352, 43), (5888, 4096, 6144, 4352, 329), (6144, 4096, 6400, 4352, 107), (6400, 4096, 6656, 4352, 141), (4096, 4352, 4352, 4608, 130), (4864, 4352, 5120, 4608, 12), (5120, 4352, 5376, 4608, 151), (5376, 4352, 5632, 4608, 3), (5632, 4352, 5888, 4608, 65), (3328, 4864, 3584, 5120, 1), (3584, 4864, 3840, 5120, 132), (3328, 5120, 3584, 5376, 18), (3584, 5120, 3840, 5376, 1), (3072, 5376, 3328, 5632, 244), (512, 8192, 768, 8448, 170), (512, 8704, 768, 8960, 9), (512, 8960, 768, 9216, 32), (256, 9216, 512, 9472, 59), (512, 9216, 768, 9472, 62), (0, 9728, 256, 9984, 127), (256, 9728, 512, 9984, 15), (0, 9984, 256, 10240, 15), (256, 9984, 512, 10240, 63), (0, 10240, 256, 10496, 41)]
# /kaggle/input/litter-windrows-batch-cala/S2A_MSIL1C_20181007T094031_N0500_R036_T33SXC_20230727T233522/S2A_MSIL1C_20181007T094031_N0500_R036_T33SXC_20230727T233522.SAFE/GRANULE/L1C_T33SXC_A017193_20181007T094027/IMG_DATA/T33SXC_20181007T094031_B02.jp2
# CRS: EPSG:32633
# Bounds: BoundingBox(left=600000.0, bottom=4190220.0, right=709800.0, top=4300020.0)
# B02 Valid Pixels: 120560400 / 120560400
# crs : EPSG:32633
# bounds : BoundingBox(left=600000.0, bottom=4190220.0, right=709800.0, top=4300020.0)
# No invalid pixels found in the bounding box
# No invalid pixels found in the bounding box
# No invalid pixels found in the bounding box
# No invalid pixels found in the bounding box
# No invalid pixels found in the bounding box
# No invalid pixels found in the bounding box
# No invalid pixels found in the bounding box
# No invalid pixels found in the bounding box
# No invalid pixels found in the bounding box
# No invalid pixels found in the bounding box
# No invalid pixels found in the bounding box
# No invalid pixels found in the bounding box
# No invalid pixels found in the bounding box
# No invalid pixels found in the bounding box
# No invalid pixels found in the bounding box
# No invalid pixels found in the bounding box
# patches per region {12: [(8448, 256, 8704, 512, 206), (8704, 256, 8960, 512, 156), (8448, 512, 8704, 768, 3)], 4: [(4096, 768, 4352, 1024, 15), (4096, 1792, 4352, 2048, 163), (4096, 2048, 4352, 2304, 106), (4096, 2304, 4352, 2560, 73), (3840, 2560, 4096, 2816, 125), (4096, 2560, 4352, 2816, 41), (4352, 2560, 4608, 2816, 64)], 5: [(3584, 2816, 3840, 3072, 195), (3840, 2816, 4096, 3072, 109), (3584, 3072, 3840, 3328, 41), (3840, 3072, 4096, 3328, 3), (3584, 3328, 3840, 3584, 16), (3584, 3584, 3840, 3840, 109), (3840, 3584, 4096, 3840, 61), (4352, 3584, 4608, 3840, 92), (4608, 3584, 4864, 3840, 247), (3840, 3840, 4096, 4096, 57), (4096, 3840, 4352, 4096, 6), (4352, 3840, 4608, 4096, 156), (4608, 3840, 4864, 4096, 9), (5376, 3840, 5632, 4096, 86), (4352, 4096, 4608, 4352, 67), (4608, 4096, 4864, 4352, 92), (5376, 4096, 5632, 4352, 241), (4096, 4352, 4352, 4608, 130), (4864, 4352, 5120, 4608, 12), (5120, 4352, 5376, 4608, 151), (5376, 4352, 5632, 4608, 3), (3328, 4864, 3584, 5120, 1), (3584, 4864, 3840, 5120, 132), (3328, 5120, 3584, 5376, 18), (3584, 5120, 3840, 5376, 1), (3072, 5376, 3328, 5632, 244)], 9: [(6400, 3840, 6656, 4096, 116), (5632, 4096, 5888, 4352, 43), (5888, 4096, 6144, 4352, 329), (6144, 4096, 6400, 4352, 107), (6400, 4096, 6656, 4352, 141), (5632, 4352, 5888, 4608, 65)], 3: [(512, 8192, 768, 8448, 170), (512, 8704, 768, 8960, 9), (512, 8960, 768, 9216, 32), (256, 9216, 512, 9472, 59), (512, 9216, 768, 9472, 62), (0, 9728, 256, 9984, 127), (256, 9728, 512, 9984, 15), (0, 9984, 256, 10240, 15), (256, 9984, 512, 10240, 63), (0, 10240, 256, 10496, 41)]}
# region center : (695400.0, 4205220.0)
# Disk usage before run:
# 5.7G	/kaggle/input/litter-windrows-batch-cala
# 68M	/kaggle/input/lw-parquet
# df: /kaggle/tmp: No such file or directory
# Filesystem      Size  Used Avail Use% Mounted on
# /dev/loop1       20G  3.1G   17G  16% /kaggle/working
# Cleaning previous acolite output
#
# Processing subregion 13/16 centered at UTM (695400.0, 4205220.0)
# UTM box: left=681000.0, bottom=4190820.0, right=709800.0, top=4219620.0
# WGS84 limit: [37.84687632680842, 17.0571854929694, 38.1000520450639, 17.39268145663381]
# setting limit : [37.84687632680842, 17.0571854929694, 38.1000520450639, 17.39268145663381]
# Settings for subregion 13: {'l2r_export_geotiff': True, 'l1r_delete_netcdf': True, 'l2w_delete_netcdf': True, 'verbosity': 5, 's2_target_res': 10, 'resampling_method': 'nearest', 'atmospheric_correction_method': 'dark_spectrum', 'dsf_exclude_bands': ['B9', 'B10'], 'geometry_type': 'grids', 'l2w_mask': False, 'glint_correction': True, 'dsf_residual_glint_correction': True, 'dsf_residual_glint_correction_method': 'alternative', 'dsf_residual_glint_wave_range': [1500, 2400], 'glint_force_band': None, 'glint_mask_rhos_wave': 1600, 'glint_mask_rhos_threshold': 0.11, 'reproject': False, 'limit': [37.84687632680842, 17.0571854929694, 38.1000520450639, 17.39268145663381]}
# Running ACOLITE processing - Generic GitHub Clone c2025-04-23T15:27:02
# Python - linux - 3.11.11 (main, Dec  4 2024, 08:55:07) [GCC 11.4.0]
# Platform - Linux 6.6.56+ - x86_64 - #1 SMP PREEMPT_DYNAMIC Sun Nov 10 10:07:59 UTC 2024
# Run ID - 20250423_155126
# Identified /kaggle/input/litter-windrows-batch-cala/S2A_MSIL1C_20181007T094031_N0500_R036_T33SXC_20230727T233522/S2A_MSIL1C_20181007T094031_N0500_R036_T33SXC_20230727T233522.SAFE as Sentinel-2 type
# Starting conversion of 1 scenes
# Starting conversion of /kaggle/input/litter-windrows-batch-cala/S2A_MSIL1C_20181007T094031_N0500_R036_T33SXC_20230727T233522/S2A_MSIL1C_20181007T094031_N0500_R036_T33SXC_20230727T233522.SAFE
# Importing metadata from L1C_T33SXC_A017193_20181007T094027
# Reading per pixel geometry
# Wrote raa (2879, 2943)
# Wrote vza (2879, 2943)
# Wrote sza (2879, 2943)
# Writing geolocation lon/lat
# Wrote lon (2879, 2943)
# Wrote lat (2879, 2943)
# Converting bands
# Converting bands: Wrote rhot_443 ((2879, 2943))
# Converting bands: Wrote rhot_492 ((2879, 2943))
# Converting bands: Wrote rhot_560 ((2879, 2943))
# Converting bands: Wrote rhot_665 ((2879, 2943))
# Converting bands: Wrote rhot_704 ((2879, 2943))
# Converting bands: Wrote rhot_740 ((2879, 2943))
# Converting bands: Wrote rhot_783 ((2879, 2943))
# Converting bands: Wrote rhot_833 ((2879, 2943))
# Converting bands: Wrote rhot_865 ((2879, 2943))
# Converting bands: Wrote rhot_945 ((2879, 2943))
# Converting bands: Wrote rhot_1373 ((2879, 2943))
# Converting bands: Wrote rhot_1614 ((2879, 2943))
# Converting bands: Wrote rhot_2202 ((2879, 2943))
# Conversion took 21.2 seconds
# Created /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L1R.nc
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L1R_rgb_rhot.png
# Running acolite for /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L1R.nc
# Getting ancillary data for 2018-10-07T09:49:58.844265+00:00 17.221E 37.974N
# Downloading file GMAO_MERRA2.20181007T090000.MET.nc
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/GMAO_MERRA2.20181007T090000.MET.nc
# Finished downloading file GMAO_MERRA2.20181007T090000.MET.nc
# Downloading file GMAO_MERRA2.20181007T100000.MET.nc
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/GMAO_MERRA2.20181007T100000.MET.nc
# Finished downloading file GMAO_MERRA2.20181007T100000.MET.nc
# No ozone file found for 2018-10-07T09:49:58.844265+00:00
# No NCEP files found for 2018-10-07T09:49:58.844265+00:00
# default uoz: 0.30 uwv: 1.50 pressure: 1013.25
# current uoz: 0.30 uwv: 1.50 pressure: 1013.25
# Using DSF atmospheric correction
# Processing with 25 tiles (5x5 tiles of 600x600 pixels)
# Writing lon
# Wrote lon (2879, 2943)
# Writing lat
# Wrote lat (2879, 2943)
# Writing sza
# Wrote sza (2879, 2943)
# Writing vza
# Wrote vza (2879, 2943)
# Writing raa
# Wrote raa (2879, 2943)
# Loading LUTs ['ACOLITE-LUT-202110-MOD1', 'ACOLITE-LUT-202110-MOD2']
# Loading LUTs took 2.3 s
# Running AOT estimation for band 1 (rhot_443)
# S2A_MSI/B1 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B1 ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Running AOT estimation for band 2 (rhot_492)
# S2A_MSI/B2 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B2 ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Running AOT estimation for band 3 (rhot_560)
# S2A_MSI/B3 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B3 ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Running AOT estimation for band 4 (rhot_665)
# S2A_MSI/B4 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B4 ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Running AOT estimation for band 5 (rhot_704)
# S2A_MSI/B5 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B5 ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Running AOT estimation for band 6 (rhot_740)
# S2A_MSI/B6 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B6 ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Running AOT estimation for band 7 (rhot_783)
# S2A_MSI/B7 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B7 ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Running AOT estimation for band 8 (rhot_833)
# S2A_MSI/B8 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B8 ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Running AOT estimation for band 8A (rhot_865)
# S2A_MSI/B8A ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B8A ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Choosing best fitting model: min_drmsd (2 bands)
# Computing RMSD for model ACOLITE-LUT-202110-MOD1
# Computing RMSD for model ACOLITE-LUT-202110-MOD2
# Selecting most common model for processing.
# ACOLITE-LUT-202110-MOD1: 100.0%: mean aot of subset = 0.06
# ACOLITE-LUT-202110-MOD2: 0.0%
# Selected ACOLITE-LUT-202110-MOD1, mean aot = 0.06
# use_revlut True
# Wrote rhot_443 (2879, 2943)
# Computing surface reflectance 1 443 0.998
# Interpolating tiles
# Wrote rhos_443 (2879, 2943)
# S2A_MSI/B1 took 3.4s (RevLUT)
# Wrote rhot_492 (2879, 2943)
# Computing surface reflectance 2 492 0.981
# Interpolating tiles
# Wrote rhos_492 (2879, 2943)
# S2A_MSI/B2 took 3.4s (RevLUT)
# Wrote rhot_560 (2879, 2943)
# Computing surface reflectance 3 560 0.924
# Interpolating tiles
# Wrote rhos_560 (2879, 2943)
# S2A_MSI/B3 took 3.5s (RevLUT)
# Wrote rhot_665 (2879, 2943)
# Computing surface reflectance 4 665 0.955
# Interpolating tiles
# Wrote rhos_665 (2879, 2943)
# S2A_MSI/B4 took 3.4s (RevLUT)
# Wrote rhot_704 (2879, 2943)
# Computing surface reflectance 5 704 0.949
# Interpolating tiles
# Wrote rhos_704 (2879, 2943)
# S2A_MSI/B5 took 3.4s (RevLUT)
# Wrote rhot_740 (2879, 2943)
# Computing surface reflectance 6 740 0.958
# Interpolating tiles
# Wrote rhos_740 (2879, 2943)
# S2A_MSI/B6 took 3.4s (RevLUT)
# Wrote rhot_783 (2879, 2943)
# Computing surface reflectance 7 783 0.984
# Interpolating tiles
# Wrote rhos_783 (2879, 2943)
# S2A_MSI/B7 took 3.5s (RevLUT)
# Wrote rhot_833 (2879, 2943)
# Computing surface reflectance 8 833 0.938
# Interpolating tiles
# Wrote rhos_833 (2879, 2943)
# S2A_MSI/B8 took 3.4s (RevLUT)
# Wrote rhot_865 (2879, 2943)
# Computing surface reflectance 8A 865 0.997
# Interpolating tiles
# Wrote rhos_865 (2879, 2943)
# S2A_MSI/B8A took 3.5s (RevLUT)
# Wrote rhot_945 (2879, 2943)
# Band 9 at 945 nm has tgas < min_tgas_rho (0.28 < 0.70)
# Wrote rhot_1373 (2879, 2943)
# Band 10 at 1373 nm has tgas < min_tgas_rho (0.01 < 0.70)
# Wrote rhot_1614 (2879, 2943)
# Computing surface reflectance 11 1614 0.959
# Interpolating tiles
# Wrote rhos_1614 (2879, 2943)
# S2A_MSI/B11 took 3.4s (RevLUT)
# Wrote rhot_2202 (2879, 2943)
# Computing surface reflectance 12 2202 0.913
# Interpolating tiles
# Wrote rhos_2202 (2879, 2943)
# S2A_MSI/B12 took 3.4s (RevLUT)
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R.nc
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_sza.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_vza.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_raa.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_443.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_443.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_492.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_492.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_560.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_560.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_665.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_665.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_704.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_704.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_740.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_740.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_783.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_783.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_833.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_833.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_865.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_865.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_945.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_1373.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_1614.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_1614.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_2202.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_2202.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rgb_rhot.png
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rgb_rhos.png
# Deleting /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L1R.nc
# Generated output files {0: {'input': '/kaggle/input/litter-windrows-batch-cala/S2A_MSIL1C_20181007T094031_N0500_R036_T33SXC_20230727T233522/S2A_MSIL1C_20181007T094031_N0500_R036_T33SXC_20230727T233522.SAFE', 'l1r': ['/kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L1R.nc'], 'l2r': ['/kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R.nc']}}
# stacking bands
# Stacked GeoTIFF saved to: /kaggle/working/stacked/S2_20181007T094031_N0500_stacked.tiff
# Stacked GeoTIFF:
# Bounds: BoundingBox(left=680370.0, bottom=4190820.0, right=709800.0, top=4219610.0)
# Dimensions: 2943 columns, 2879 rows
# Resolution: (10.0, 10.0)
# CRS: EPSG:32633
# Number of bands: 11
# Band descriptions: ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12')
# Percentage of invalid values (NaN, Inf, negative) across all bands: 0.31%
# patch dir /kaggle/working/patches/S2_20181007T094031_N0500
# cropping  patch (8448, 256, 8704, 512, 206)
# patch pathname /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_684480_4192780.tiff
# Cropped GeoTIFF saved to: /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_684480_4192780.tiff
# Cropped GeoTIFF:
# Bounds: BoundingBox(left=684480.0, bottom=4192780.0, right=687040.0, top=4195340.0)
# Dimensions: 256 columns, 256 rows
# Resolution: (10.0, 10.0)
# CRS: EPSG:32633
# Number of bands: 11
# Band descriptions: ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12')
# patch mask shape (256, 256)
# cropping  patch (8704, 256, 8960, 512, 156)
# patch pathname /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_687040_4192780.tiff
# Cropped GeoTIFF saved to: /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_687040_4192780.tiff
# Cropped GeoTIFF:
# Bounds: BoundingBox(left=687040.0, bottom=4192780.0, right=689600.0, top=4195340.0)
# Dimensions: 256 columns, 256 rows
# Resolution: (10.0, 10.0)
# CRS: EPSG:32633
# Number of bands: 11
# Band descriptions: ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12')
# patch mask shape (256, 256)
# cropping  patch (8448, 512, 8704, 768, 3)
# patch pathname /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_684480_4195340.tiff
# Cropped GeoTIFF saved to: /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_684480_4195340.tiff
# Cropped GeoTIFF:
# Bounds: BoundingBox(left=684480.0, bottom=4195340.0, right=687040.0, top=4197900.0)
# Dimensions: 256 columns, 256 rows
# Resolution: (10.0, 10.0)
# CRS: EPSG:32633
# Number of bands: 11
# Band descriptions: ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12')
# patch mask shape (256, 256)
#
# Disk usage after run:
# 5.7G	/kaggle/input/litter-windrows-batch-cala
# 68M	/kaggle/input/lw-parquet
# df: /kaggle/tmp: No such file or directory
# Filesystem      Size  Used Avail Use% Mounted on
# /dev/loop1       20G  3.3G   17G  17% /kaggle/working
# region center : (642000.0, 4205220.0)
# Disk usage before run:
# 5.7G	/kaggle/input/litter-windrows-batch-cala
# 68M	/kaggle/input/lw-parquet
# df: /kaggle/tmp: No such file or directory
# Filesystem      Size  Used Avail Use% Mounted on
# /dev/loop1       20G  3.0G   17G  15% /kaggle/working
# Cleaning previous acolite output
#
# Processing subregion 5/16 centered at UTM (642000.0, 4205220.0)
# UTM box: left=627000.0, bottom=4190220.0, right=657000.0, top=4220220.0
# WGS84 limit: [37.85059285703062, 16.443551296452128, 38.11617593185255, 16.790968373796577]
# setting limit : [37.85059285703062, 16.443551296452128, 38.11617593185255, 16.790968373796577]
# Settings for subregion 5: {'l2r_export_geotiff': True, 'l1r_delete_netcdf': True, 'l2w_delete_netcdf': True, 'verbosity': 5, 's2_target_res': 10, 'resampling_method': 'nearest', 'atmospheric_correction_method': 'dark_spectrum', 'dsf_exclude_bands': ['B9', 'B10'], 'geometry_type': 'grids', 'l2w_mask': False, 'glint_correction': True, 'dsf_residual_glint_correction': True, 'dsf_residual_glint_correction_method': 'alternative', 'dsf_residual_glint_wave_range': [1500, 2400], 'glint_force_band': None, 'glint_mask_rhos_wave': 1600, 'glint_mask_rhos_threshold': 0.11, 'reproject': False, 'limit': [37.85059285703062, 16.443551296452128, 38.11617593185255, 16.790968373796577]}
# Running ACOLITE processing - Generic GitHub Clone c2025-04-23T15:27:02
# Python - linux - 3.11.11 (main, Dec  4 2024, 08:55:07) [GCC 11.4.0]
# Platform - Linux 6.6.56+ - x86_64 - #1 SMP PREEMPT_DYNAMIC Sun Nov 10 10:07:59 UTC 2024
# Run ID - 20250423_155300
# Identified /kaggle/input/litter-windrows-batch-cala/S2A_MSIL1C_20181007T094031_N0500_R036_T33SXC_20230727T233522/S2A_MSIL1C_20181007T094031_N0500_R036_T33SXC_20230727T233522.SAFE as Sentinel-2 type
# Starting conversion of 1 scenes
# Starting conversion of /kaggle/input/litter-windrows-batch-cala/S2A_MSIL1C_20181007T094031_N0500_R036_T33SXC_20230727T233522/S2A_MSIL1C_20181007T094031_N0500_R036_T33SXC_20230727T233522.SAFE
# Importing metadata from L1C_T33SXC_A017193_20181007T094027
# Reading per pixel geometry
# Wrote raa (2999, 3104)
# Wrote vza (2999, 3104)
# Wrote sza (2999, 3104)
# Writing geolocation lon/lat
# Wrote lon (2999, 3104)
# Wrote lat (2999, 3104)
# Converting bands
# Converting bands: Wrote rhot_443 ((2999, 3104))
# Converting bands: Wrote rhot_492 ((2999, 3104))
# Converting bands: Wrote rhot_560 ((2999, 3104))
# Converting bands: Wrote rhot_665 ((2999, 3104))
# Converting bands: Wrote rhot_704 ((2999, 3104))
# Converting bands: Wrote rhot_740 ((2999, 3104))
# Converting bands: Wrote rhot_783 ((2999, 3104))
# Converting bands: Wrote rhot_833 ((2999, 3104))
# Converting bands: Wrote rhot_865 ((2999, 3104))
# Converting bands: Wrote rhot_945 ((2999, 3104))
# Converting bands: Wrote rhot_1373 ((2999, 3104))
# Converting bands: Wrote rhot_1614 ((2999, 3104))
# Converting bands: Wrote rhot_2202 ((2999, 3104))
# Conversion took 19.3 seconds
# Created /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L1R.nc
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L1R_rgb_rhot.png
# Running acolite for /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L1R.nc
# Getting ancillary data for 2018-10-07T09:49:58.844265+00:00 16.618E 37.983N
# Downloading file GMAO_MERRA2.20181007T090000.MET.nc
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/GMAO_MERRA2.20181007T090000.MET.nc
# Finished downloading file GMAO_MERRA2.20181007T090000.MET.nc
# Downloading file GMAO_MERRA2.20181007T100000.MET.nc
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/GMAO_MERRA2.20181007T100000.MET.nc
# Finished downloading file GMAO_MERRA2.20181007T100000.MET.nc
# No ozone file found for 2018-10-07T09:49:58.844265+00:00
# No NCEP files found for 2018-10-07T09:49:58.844265+00:00
# default uoz: 0.30 uwv: 1.50 pressure: 1013.25
# current uoz: 0.30 uwv: 1.50 pressure: 1013.25
# Using DSF atmospheric correction
# Processing with 30 tiles (5x6 tiles of 600x600 pixels)
# Writing lon
# Wrote lon (2999, 3104)
# Writing lat
# Wrote lat (2999, 3104)
# Writing sza
# Wrote sza (2999, 3104)
# Writing vza
# Wrote vza (2999, 3104)
# Writing raa
# Wrote raa (2999, 3104)
# Loading LUTs ['ACOLITE-LUT-202110-MOD1', 'ACOLITE-LUT-202110-MOD2']
# Loading LUTs took 2.3 s
# Running AOT estimation for band 1 (rhot_443)
# S2A_MSI/B1 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B1 ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Running AOT estimation for band 2 (rhot_492)
# S2A_MSI/B2 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B2 ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Running AOT estimation for band 3 (rhot_560)
# S2A_MSI/B3 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B3 ACOLITE-LUT-202110-MOD2 took 0.002s (RevLUT)
# Running AOT estimation for band 4 (rhot_665)
# S2A_MSI/B4 ACOLITE-LUT-202110-MOD1 took 0.002s (RevLUT)
# S2A_MSI/B4 ACOLITE-LUT-202110-MOD2 took 0.002s (RevLUT)
# Running AOT estimation for band 5 (rhot_704)
# S2A_MSI/B5 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B5 ACOLITE-LUT-202110-MOD2 took 0.002s (RevLUT)
# Running AOT estimation for band 6 (rhot_740)
# S2A_MSI/B6 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B6 ACOLITE-LUT-202110-MOD2 took 0.002s (RevLUT)
# Running AOT estimation for band 7 (rhot_783)
# S2A_MSI/B7 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B7 ACOLITE-LUT-202110-MOD2 took 0.002s (RevLUT)
# Running AOT estimation for band 8 (rhot_833)
# S2A_MSI/B8 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B8 ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Running AOT estimation for band 8A (rhot_865)
# S2A_MSI/B8A ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B8A ACOLITE-LUT-202110-MOD2 took 0.002s (RevLUT)
# Choosing best fitting model: min_drmsd (2 bands)
# Computing RMSD for model ACOLITE-LUT-202110-MOD1
# Computing RMSD for model ACOLITE-LUT-202110-MOD2
# Selecting most common model for processing.
# ACOLITE-LUT-202110-MOD1: 100.0%: mean aot of subset = 0.07
# ACOLITE-LUT-202110-MOD2: 0.0%
# Selected ACOLITE-LUT-202110-MOD1, mean aot = 0.07
# use_revlut True
# Wrote rhot_443 (2999, 3104)
# Computing surface reflectance 1 443 0.998
# Interpolating tiles
# Wrote rhos_443 (2999, 3104)
# S2A_MSI/B1 took 3.8s (RevLUT)
# Wrote rhot_492 (2999, 3104)
# Computing surface reflectance 2 492 0.981
# Interpolating tiles
# Wrote rhos_492 (2999, 3104)
# S2A_MSI/B2 took 3.8s (RevLUT)
# Wrote rhot_560 (2999, 3104)
# Computing surface reflectance 3 560 0.924
# Interpolating tiles
# Wrote rhos_560 (2999, 3104)
# S2A_MSI/B3 took 3.8s (RevLUT)
# Wrote rhot_665 (2999, 3104)
# Computing surface reflectance 4 665 0.955
# Interpolating tiles
# Wrote rhos_665 (2999, 3104)
# S2A_MSI/B4 took 3.9s (RevLUT)
# Wrote rhot_704 (2999, 3104)
# Computing surface reflectance 5 704 0.949
# Interpolating tiles
# Wrote rhos_704 (2999, 3104)
# S2A_MSI/B5 took 3.8s (RevLUT)
# Wrote rhot_740 (2999, 3104)
# Computing surface reflectance 6 740 0.958
# Interpolating tiles
# Wrote rhos_740 (2999, 3104)
# S2A_MSI/B6 took 3.8s (RevLUT)
# Wrote rhot_783 (2999, 3104)
# Computing surface reflectance 7 783 0.984
# Interpolating tiles
# Wrote rhos_783 (2999, 3104)
# S2A_MSI/B7 took 3.8s (RevLUT)
# Wrote rhot_833 (2999, 3104)
# Computing surface reflectance 8 833 0.938
# Interpolating tiles
# Wrote rhos_833 (2999, 3104)
# S2A_MSI/B8 took 3.8s (RevLUT)
# Wrote rhot_865 (2999, 3104)
# Computing surface reflectance 8A 865 0.997
# Interpolating tiles
# Wrote rhos_865 (2999, 3104)
# S2A_MSI/B8A took 3.8s (RevLUT)
# Wrote rhot_945 (2999, 3104)
# Band 9 at 945 nm has tgas < min_tgas_rho (0.28 < 0.70)
# Wrote rhot_1373 (2999, 3104)
# Band 10 at 1373 nm has tgas < min_tgas_rho (0.01 < 0.70)
# Wrote rhot_1614 (2999, 3104)
# Computing surface reflectance 11 1614 0.959
# Interpolating tiles
# Wrote rhos_1614 (2999, 3104)
# S2A_MSI/B11 took 3.9s (RevLUT)
# Wrote rhot_2202 (2999, 3104)
# Computing surface reflectance 12 2202 0.913
# Interpolating tiles
# Wrote rhos_2202 (2999, 3104)
# S2A_MSI/B12 took 3.8s (RevLUT)
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R.nc
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_sza.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_vza.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_raa.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_443.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_443.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_492.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_492.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_560.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_560.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_665.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_665.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_704.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_704.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_740.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_740.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_783.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_783.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_833.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_833.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_865.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_865.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_945.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_1373.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_1614.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_1614.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_2202.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_2202.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rgb_rhot.png
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rgb_rhos.png
# Deleting /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L1R.nc
# Generated output files {0: {'input': '/kaggle/input/litter-windrows-batch-cala/S2A_MSIL1C_20181007T094031_N0500_R036_T33SXC_20230727T233522/S2A_MSIL1C_20181007T094031_N0500_R036_T33SXC_20230727T233522.SAFE', 'l1r': ['/kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L1R.nc'], 'l2r': ['/kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R.nc']}}
# stacking bands
# Stacked GeoTIFF saved to: /kaggle/working/stacked/S2_20181007T094031_N0500_stacked.tiff
# Stacked GeoTIFF:
# Bounds: BoundingBox(left=626540.0, bottom=4190220.0, right=657580.0, top=4220210.0)
# Dimensions: 3104 columns, 2999 rows
# Resolution: (10.0, 10.0)
# CRS: EPSG:32633
# Number of bands: 11
# Band descriptions: ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12')
# Percentage of invalid values (NaN, Inf, negative) across all bands: 0.83%
# patch dir /kaggle/working/patches/S2_20181007T094031_N0500
# cropping  patch (4096, 768, 4352, 1024, 15)
# patch pathname /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_640960_4197900.tiff
# Cropped GeoTIFF saved to: /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_640960_4197900.tiff
# Cropped GeoTIFF:
# Bounds: BoundingBox(left=640960.0, bottom=4197900.0, right=643520.0, top=4200460.0)
# Dimensions: 256 columns, 256 rows
# Resolution: (10.0, 10.0)
# CRS: EPSG:32633
# Number of bands: 11
# Band descriptions: ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12')
# patch mask shape (256, 256)
# cropping  patch (4096, 1792, 4352, 2048, 163)
# patch pathname /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_640960_4208140.tiff
# Cropped GeoTIFF saved to: /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_640960_4208140.tiff
# Cropped GeoTIFF:
# Bounds: BoundingBox(left=640960.0, bottom=4208140.0, right=643520.0, top=4210700.0)
# Dimensions: 256 columns, 256 rows
# Resolution: (10.0, 10.0)
# CRS: EPSG:32633
# Number of bands: 11
# Band descriptions: ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12')
# patch mask shape (256, 256)
# cropping  patch (4096, 2048, 4352, 2304, 106)
# patch pathname /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_640960_4210700.tiff
# Cropped GeoTIFF saved to: /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_640960_4210700.tiff
# Cropped GeoTIFF:
# Bounds: BoundingBox(left=640960.0, bottom=4210700.0, right=643520.0, top=4213260.0)
# Dimensions: 256 columns, 256 rows
# Resolution: (10.0, 10.0)
# CRS: EPSG:32633
# Number of bands: 11
# Band descriptions: ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12')
# patch mask shape (256, 256)
# cropping  patch (4096, 2304, 4352, 2560, 73)
# patch pathname /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_640960_4213260.tiff
# Cropped GeoTIFF saved to: /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_640960_4213260.tiff
# Cropped GeoTIFF:
# Bounds: BoundingBox(left=640960.0, bottom=4213260.0, right=643520.0, top=4215820.0)
# Dimensions: 256 columns, 256 rows
# Resolution: (10.0, 10.0)
# CRS: EPSG:32633
# Number of bands: 11
# Band descriptions: ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12')
# patch mask shape (256, 256)
# cropping  patch (3840, 2560, 4096, 2816, 125)
# patch pathname /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_638400_4215820.tiff
# Cropped GeoTIFF saved to: /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_638400_4215820.tiff
# Cropped GeoTIFF:
# Bounds: BoundingBox(left=638400.0, bottom=4215820.0, right=640960.0, top=4218380.0)
# Dimensions: 256 columns, 256 rows
# Resolution: (10.0, 10.0)
# CRS: EPSG:32633
# Number of bands: 11
# Band descriptions: ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12')
# patch mask shape (256, 256)
# cropping  patch (4096, 2560, 4352, 2816, 41)
# patch pathname /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_640960_4215820.tiff
# Cropped GeoTIFF saved to: /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_640960_4215820.tiff
# Cropped GeoTIFF:
# Bounds: BoundingBox(left=640960.0, bottom=4215820.0, right=643520.0, top=4218380.0)
# Dimensions: 256 columns, 256 rows
# Resolution: (10.0, 10.0)
# CRS: EPSG:32633
# Number of bands: 11
# Band descriptions: ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12')
# patch mask shape (256, 256)
# cropping  patch (4352, 2560, 4608, 2816, 64)
# patch pathname /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_643520_4215820.tiff
# Cropped GeoTIFF saved to: /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_643520_4215820.tiff
# Cropped GeoTIFF:
# Bounds: BoundingBox(left=643520.0, bottom=4215820.0, right=646080.0, top=4218380.0)
# Dimensions: 256 columns, 256 rows
# Resolution: (10.0, 10.0)
# CRS: EPSG:32633
# Number of bands: 11
# Band descriptions: ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12')
# patch mask shape (256, 256)
#
# Disk usage after run:
# 5.7G	/kaggle/input/litter-windrows-batch-cala
# 68M	/kaggle/input/lw-parquet
# df: /kaggle/tmp: No such file or directory
# Filesystem      Size  Used Avail Use% Mounted on
# /dev/loop1       20G  3.5G   17G  18% /kaggle/working
# region center : (642000.0, 4232220.0)
# Disk usage before run:
# 5.7G	/kaggle/input/litter-windrows-batch-cala
# 68M	/kaggle/input/lw-parquet
# df: /kaggle/tmp: No such file or directory
# Filesystem      Size  Used Avail Use% Mounted on
# /dev/loop1       20G  3.2G   17G  16% /kaggle/working
# Cleaning previous acolite output
#
# Processing subregion 6/16 centered at UTM (642000.0, 4232220.0)
# UTM box: left=627000.0, bottom=4217220.0, right=657000.0, top=4247220.0
# WGS84 limit: [38.09386462332733, 16.44832409449025, 38.35939478644499, 16.796946287199965]
# setting limit : [38.09386462332733, 16.44832409449025, 38.35939478644499, 16.796946287199965]
# Settings for subregion 6: {'l2r_export_geotiff': True, 'l1r_delete_netcdf': True, 'l2w_delete_netcdf': True, 'verbosity': 5, 's2_target_res': 10, 'resampling_method': 'nearest', 'atmospheric_correction_method': 'dark_spectrum', 'dsf_exclude_bands': ['B9', 'B10'], 'geometry_type': 'grids', 'l2w_mask': False, 'glint_correction': True, 'dsf_residual_glint_correction': True, 'dsf_residual_glint_correction_method': 'alternative', 'dsf_residual_glint_wave_range': [1500, 2400], 'glint_force_band': None, 'glint_mask_rhos_wave': 1600, 'glint_mask_rhos_threshold': 0.11, 'reproject': False, 'limit': [38.09386462332733, 16.44832409449025, 38.35939478644499, 16.796946287199965]}
# Running ACOLITE processing - Generic GitHub Clone c2025-04-23T15:27:02
# Python - linux - 3.11.11 (main, Dec  4 2024, 08:55:07) [GCC 11.4.0]
# Platform - Linux 6.6.56+ - x86_64 - #1 SMP PREEMPT_DYNAMIC Sun Nov 10 10:07:59 UTC 2024
# Run ID - 20250423_155438
# Identified /kaggle/input/litter-windrows-batch-cala/S2A_MSIL1C_20181007T094031_N0500_R036_T33SXC_20230727T233522/S2A_MSIL1C_20181007T094031_N0500_R036_T33SXC_20230727T233522.SAFE as Sentinel-2 type
# Starting conversion of 1 scenes
# Starting conversion of /kaggle/input/litter-windrows-batch-cala/S2A_MSIL1C_20181007T094031_N0500_R036_T33SXC_20230727T233522/S2A_MSIL1C_20181007T094031_N0500_R036_T33SXC_20230727T233522.SAFE
# Importing metadata from L1C_T33SXC_A017193_20181007T094027
# Reading per pixel geometry
# Wrote raa (2999, 3106)
# Wrote vza (2999, 3106)
# Wrote sza (2999, 3106)
# Writing geolocation lon/lat
# Wrote lon (2999, 3106)
# Wrote lat (2999, 3106)
# Converting bands
# Converting bands: Wrote rhot_443 ((2999, 3106))
# Converting bands: Wrote rhot_492 ((2999, 3106))
# Converting bands: Wrote rhot_560 ((2999, 3106))
# Converting bands: Wrote rhot_665 ((2999, 3106))
# Converting bands: Wrote rhot_704 ((2999, 3106))
# Converting bands: Wrote rhot_740 ((2999, 3106))
# Converting bands: Wrote rhot_783 ((2999, 3106))
# Converting bands: Wrote rhot_833 ((2999, 3106))
# Converting bands: Wrote rhot_865 ((2999, 3106))
# Converting bands: Wrote rhot_945 ((2999, 3106))
# Converting bands: Wrote rhot_1373 ((2999, 3106))
# Converting bands: Wrote rhot_1614 ((2999, 3106))
# Converting bands: Wrote rhot_2202 ((2999, 3106))
# Conversion took 19.6 seconds
# Created /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L1R.nc
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L1R_rgb_rhot.png
# Running acolite for /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L1R.nc
# Getting ancillary data for 2018-10-07T09:49:58.844265+00:00 16.623E 38.227N
# Downloading file GMAO_MERRA2.20181007T090000.MET.nc
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/GMAO_MERRA2.20181007T090000.MET.nc
# Finished downloading file GMAO_MERRA2.20181007T090000.MET.nc
# Downloading file GMAO_MERRA2.20181007T100000.MET.nc
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/GMAO_MERRA2.20181007T100000.MET.nc
# Finished downloading file GMAO_MERRA2.20181007T100000.MET.nc
# No ozone file found for 2018-10-07T09:49:58.844265+00:00
# No NCEP files found for 2018-10-07T09:49:58.844265+00:00
# default uoz: 0.30 uwv: 1.50 pressure: 1013.25
# current uoz: 0.30 uwv: 1.50 pressure: 1013.25
# Using DSF atmospheric correction
# Processing with 30 tiles (5x6 tiles of 600x600 pixels)
# Writing lon
# Wrote lon (2999, 3106)
# Writing lat
# Wrote lat (2999, 3106)
# Writing sza
# Wrote sza (2999, 3106)
# Writing vza
# Wrote vza (2999, 3106)
# Writing raa
# Wrote raa (2999, 3106)
# Loading LUTs ['ACOLITE-LUT-202110-MOD1', 'ACOLITE-LUT-202110-MOD2']
# Loading LUTs took 2.3 s
# Running AOT estimation for band 1 (rhot_443)
# S2A_MSI/B1 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B1 ACOLITE-LUT-202110-MOD2 took 0.002s (RevLUT)
# Running AOT estimation for band 2 (rhot_492)
# S2A_MSI/B2 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B2 ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Running AOT estimation for band 3 (rhot_560)
# S2A_MSI/B3 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B3 ACOLITE-LUT-202110-MOD2 took 0.002s (RevLUT)
# Running AOT estimation for band 4 (rhot_665)
# S2A_MSI/B4 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B4 ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Running AOT estimation for band 5 (rhot_704)
# S2A_MSI/B5 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B5 ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Running AOT estimation for band 6 (rhot_740)
# S2A_MSI/B6 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B6 ACOLITE-LUT-202110-MOD2 took 0.002s (RevLUT)
# Running AOT estimation for band 7 (rhot_783)
# S2A_MSI/B7 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B7 ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Running AOT estimation for band 8 (rhot_833)
# S2A_MSI/B8 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B8 ACOLITE-LUT-202110-MOD2 took 0.002s (RevLUT)
# Running AOT estimation for band 8A (rhot_865)
# S2A_MSI/B8A ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B8A ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Choosing best fitting model: min_drmsd (2 bands)
# Computing RMSD for model ACOLITE-LUT-202110-MOD1
# Computing RMSD for model ACOLITE-LUT-202110-MOD2
# Selecting most common model for processing.
# ACOLITE-LUT-202110-MOD1: 100.0%: mean aot of subset = 0.07
# ACOLITE-LUT-202110-MOD2: 0.0%
# Selected ACOLITE-LUT-202110-MOD1, mean aot = 0.07
# use_revlut True
# Wrote rhot_443 (2999, 3106)
# Computing surface reflectance 1 443 0.998
# Interpolating tiles
# Wrote rhos_443 (2999, 3106)
# S2A_MSI/B1 took 3.8s (RevLUT)
# Wrote rhot_492 (2999, 3106)
# Computing surface reflectance 2 492 0.981
# Interpolating tiles
# Wrote rhos_492 (2999, 3106)
# S2A_MSI/B2 took 3.8s (RevLUT)
# Wrote rhot_560 (2999, 3106)
# Computing surface reflectance 3 560 0.924
# Interpolating tiles
# Wrote rhos_560 (2999, 3106)
# S2A_MSI/B3 took 4.0s (RevLUT)
# Wrote rhot_665 (2999, 3106)
# Computing surface reflectance 4 665 0.955
# Interpolating tiles
# Wrote rhos_665 (2999, 3106)
# S2A_MSI/B4 took 3.8s (RevLUT)
# Wrote rhot_704 (2999, 3106)
# Computing surface reflectance 5 704 0.948
# Interpolating tiles
# Wrote rhos_704 (2999, 3106)
# S2A_MSI/B5 took 3.8s (RevLUT)
# Wrote rhot_740 (2999, 3106)
# Computing surface reflectance 6 740 0.958
# Interpolating tiles
# Wrote rhos_740 (2999, 3106)
# S2A_MSI/B6 took 3.9s (RevLUT)
# Wrote rhot_783 (2999, 3106)
# Computing surface reflectance 7 783 0.984
# Interpolating tiles
# Wrote rhos_783 (2999, 3106)
# S2A_MSI/B7 took 3.9s (RevLUT)
# Wrote rhot_833 (2999, 3106)
# Computing surface reflectance 8 833 0.938
# Interpolating tiles
# Wrote rhos_833 (2999, 3106)
# S2A_MSI/B8 took 3.8s (RevLUT)
# Wrote rhot_865 (2999, 3106)
# Computing surface reflectance 8A 865 0.997
# Interpolating tiles
# Wrote rhos_865 (2999, 3106)
# S2A_MSI/B8A took 3.8s (RevLUT)
# Wrote rhot_945 (2999, 3106)
# Band 9 at 945 nm has tgas < min_tgas_rho (0.28 < 0.70)
# Wrote rhot_1373 (2999, 3106)
# Band 10 at 1373 nm has tgas < min_tgas_rho (0.01 < 0.70)
# Wrote rhot_1614 (2999, 3106)
# Computing surface reflectance 11 1614 0.959
# Interpolating tiles
# Wrote rhos_1614 (2999, 3106)
# S2A_MSI/B11 took 3.8s (RevLUT)
# Wrote rhot_2202 (2999, 3106)
# Computing surface reflectance 12 2202 0.913
# Interpolating tiles
# Wrote rhos_2202 (2999, 3106)
# S2A_MSI/B12 took 3.9s (RevLUT)
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R.nc
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_sza.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_vza.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_raa.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_443.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_443.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_492.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_492.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_560.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_560.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_665.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_665.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_704.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_704.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_740.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_740.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_783.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_783.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_833.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_833.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_865.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_865.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_945.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_1373.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_1614.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_1614.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_2202.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_2202.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rgb_rhot.png
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rgb_rhos.png
# Deleting /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L1R.nc
# Generated output files {0: {'input': '/kaggle/input/litter-windrows-batch-cala/S2A_MSIL1C_20181007T094031_N0500_R036_T33SXC_20230727T233522/S2A_MSIL1C_20181007T094031_N0500_R036_T33SXC_20230727T233522.SAFE', 'l1r': ['/kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L1R.nc'], 'l2r': ['/kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R.nc']}}
# stacking bands
# Stacked GeoTIFF saved to: /kaggle/working/stacked/S2_20181007T094031_N0500_stacked.tiff
# Stacked GeoTIFF:
# Bounds: BoundingBox(left=626530.0, bottom=4217220.0, right=657590.0, top=4247210.0)
# Dimensions: 3106 columns, 2999 rows
# Resolution: (10.0, 10.0)
# CRS: EPSG:32633
# Number of bands: 11
# Band descriptions: ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12')
# Percentage of invalid values (NaN, Inf, negative) across all bands: 0.83%
# patch dir /kaggle/working/patches/S2_20181007T094031_N0500
# cropping  patch (3584, 2816, 3840, 3072, 195)
# patch pathname /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_635840_4218380.tiff
# Cropped GeoTIFF saved to: /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_635840_4218380.tiff
# Cropped GeoTIFF:
# Bounds: BoundingBox(left=635840.0, bottom=4218380.0, right=638400.0, top=4220940.0)
# Dimensions: 256 columns, 256 rows
# Resolution: (10.0, 10.0)
# CRS: EPSG:32633
# Number of bands: 11
# Band descriptions: ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12')
# patch mask shape (256, 256)
# cropping  patch (3840, 2816, 4096, 3072, 109)
# patch pathname /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_638400_4218380.tiff
# Cropped GeoTIFF saved to: /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_638400_4218380.tiff
# Cropped GeoTIFF:
# Bounds: BoundingBox(left=638400.0, bottom=4218380.0, right=640960.0, top=4220940.0)
# Dimensions: 256 columns, 256 rows
# Resolution: (10.0, 10.0)
# CRS: EPSG:32633
# Number of bands: 11
# Band descriptions: ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12')
# patch mask shape (256, 256)
# cropping  patch (3584, 3072, 3840, 3328, 41)
# patch pathname /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_635840_4220940.tiff
# Cropped GeoTIFF saved to: /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_635840_4220940.tiff
# Cropped GeoTIFF:
# Bounds: BoundingBox(left=635840.0, bottom=4220940.0, right=638400.0, top=4223500.0)
# Dimensions: 256 columns, 256 rows
# Resolution: (10.0, 10.0)
# CRS: EPSG:32633
# Number of bands: 11
# Band descriptions: ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12')
# patch mask shape (256, 256)
# cropping  patch (3840, 3072, 4096, 3328, 3)
# patch pathname /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_638400_4220940.tiff
# ...
# Starting conversion of 1 scenes
# Starting conversion of /kaggle/input/litter-windrows-batch-cala/S2A_MSIL1C_20181007T094031_N0500_R036_T33SXC_20230727T233522/S2A_MSIL1C_20181007T094031_N0500_R036_T33SXC_20230727T233522.SAFE
# Importing metadata from L1C_T33SXC_A017193_20181007T094027
# Reading per pixel geometry
# Wrote raa (2941, 3050)
# Wrote vza (2941, 3050)
# Wrote sza (2941, 3050)
# Writing geolocation lon/lat
# Wrote lon (2941, 3050)
# Wrote lat (2941, 3050)
# Converting bands
# Converting bands: Wrote rhot_443 ((2941, 3050))
# Converting bands: Wrote rhot_492 ((2941, 3050))
# Converting bands: Wrote rhot_560 ((2941, 3050))
# Converting bands: Wrote rhot_665 ((2941, 3050))
# Converting bands: Wrote rhot_704 ((2941, 3050))
# Converting bands: Wrote rhot_740 ((2941, 3050))
# Converting bands: Wrote rhot_783 ((2941, 3050))
# Converting bands: Wrote rhot_833 ((2941, 3050))
# Converting bands: Wrote rhot_865 ((2941, 3050))
# Converting bands: Wrote rhot_945 ((2941, 3050))
# Converting bands: Wrote rhot_1373 ((2941, 3050))
# Converting bands: Wrote rhot_1614 ((2941, 3050))
# Converting bands: Wrote rhot_2202 ((2941, 3050))
# Conversion took 20.1 seconds
# Created /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L1R.nc
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L1R_rgb_rhot.png
# Running acolite for /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L1R.nc
# Getting ancillary data for 2018-10-07T09:49:58.844265+00:00 16.326E 38.709N
# Downloading file GMAO_MERRA2.20181007T090000.MET.nc
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/GMAO_MERRA2.20181007T090000.MET.nc
# Finished downloading file GMAO_MERRA2.20181007T090000.MET.nc
# Downloading file GMAO_MERRA2.20181007T100000.MET.nc
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/GMAO_MERRA2.20181007T100000.MET.nc
# Finished downloading file GMAO_MERRA2.20181007T100000.MET.nc
# No ozone file found for 2018-10-07T09:49:58.844265+00:00
# No NCEP files found for 2018-10-07T09:49:58.844265+00:00
# default uoz: 0.30 uwv: 1.50 pressure: 1013.25
# current uoz: 0.30 uwv: 1.50 pressure: 1013.25
# Using DSF atmospheric correction
# Processing with 30 tiles (5x6 tiles of 600x600 pixels)
# Writing lon
# Wrote lon (2941, 3050)
# Writing lat
# Wrote lat (2941, 3050)
# Writing sza
# Wrote sza (2941, 3050)
# Writing vza
# Wrote vza (2941, 3050)
# Writing raa
# Wrote raa (2941, 3050)
# Loading LUTs ['ACOLITE-LUT-202110-MOD1', 'ACOLITE-LUT-202110-MOD2']
# Loading LUTs took 2.4 s
# Running AOT estimation for band 1 (rhot_443)
# S2A_MSI/B1 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B1 ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Running AOT estimation for band 2 (rhot_492)
# S2A_MSI/B2 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B2 ACOLITE-LUT-202110-MOD2 took 0.002s (RevLUT)
# Running AOT estimation for band 3 (rhot_560)
# S2A_MSI/B3 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B3 ACOLITE-LUT-202110-MOD2 took 0.002s (RevLUT)
# Running AOT estimation for band 4 (rhot_665)
# S2A_MSI/B4 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B4 ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Running AOT estimation for band 5 (rhot_704)
# S2A_MSI/B5 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B5 ACOLITE-LUT-202110-MOD2 took 0.002s (RevLUT)
# Running AOT estimation for band 6 (rhot_740)
# S2A_MSI/B6 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B6 ACOLITE-LUT-202110-MOD2 took 0.002s (RevLUT)
# Running AOT estimation for band 7 (rhot_783)
# S2A_MSI/B7 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B7 ACOLITE-LUT-202110-MOD2 took 0.002s (RevLUT)
# Running AOT estimation for band 8 (rhot_833)
# S2A_MSI/B8 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B8 ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Running AOT estimation for band 8A (rhot_865)
# S2A_MSI/B8A ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B8A ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Choosing best fitting model: min_drmsd (2 bands)
# Computing RMSD for model ACOLITE-LUT-202110-MOD1
# Computing RMSD for model ACOLITE-LUT-202110-MOD2
# Selecting most common model for processing.
# ACOLITE-LUT-202110-MOD1: 63.3%: mean aot of subset = 0.21
# ACOLITE-LUT-202110-MOD2: 36.7%: mean aot of subset = 0.21
# Selected ACOLITE-LUT-202110-MOD1, mean aot = 0.20
# use_revlut True
# Wrote rhot_443 (2941, 3050)
# Computing surface reflectance 1 443 0.998
# Interpolating tiles
# Wrote rhos_443 (2941, 3050)
# S2A_MSI/B1 took 3.8s (RevLUT)
# Wrote rhot_492 (2941, 3050)
# Computing surface reflectance 2 492 0.981
# Interpolating tiles
# Wrote rhos_492 (2941, 3050)
# S2A_MSI/B2 took 3.7s (RevLUT)
# Wrote rhot_560 (2941, 3050)
# Computing surface reflectance 3 560 0.923
# Interpolating tiles
# Wrote rhos_560 (2941, 3050)
# S2A_MSI/B3 took 3.8s (RevLUT)
# Wrote rhot_665 (2941, 3050)
# Computing surface reflectance 4 665 0.955
# Interpolating tiles
# Wrote rhos_665 (2941, 3050)
# S2A_MSI/B4 took 3.8s (RevLUT)
# Wrote rhot_704 (2941, 3050)
# Computing surface reflectance 5 704 0.948
# Interpolating tiles
# Wrote rhos_704 (2941, 3050)
# S2A_MSI/B5 took 3.8s (RevLUT)
# Wrote rhot_740 (2941, 3050)
# Computing surface reflectance 6 740 0.958
# Interpolating tiles
# Wrote rhos_740 (2941, 3050)
# S2A_MSI/B6 took 4.4s (RevLUT)
# Wrote rhot_783 (2941, 3050)
# Computing surface reflectance 7 783 0.984
# Interpolating tiles
# Wrote rhos_783 (2941, 3050)
# S2A_MSI/B7 took 3.8s (RevLUT)
# Wrote rhot_833 (2941, 3050)
# Computing surface reflectance 8 833 0.937
# Interpolating tiles
# Wrote rhos_833 (2941, 3050)
# S2A_MSI/B8 took 3.8s (RevLUT)
# Wrote rhot_865 (2941, 3050)
# Computing surface reflectance 8A 865 0.997
# Interpolating tiles
# Wrote rhos_865 (2941, 3050)
# S2A_MSI/B8A took 3.8s (RevLUT)
# Wrote rhot_945 (2941, 3050)
# Band 9 at 945 nm has tgas < min_tgas_rho (0.28 < 0.70)
# Wrote rhot_1373 (2941, 3050)
# Band 10 at 1373 nm has tgas < min_tgas_rho (0.01 < 0.70)
# Wrote rhot_1614 (2941, 3050)
# Computing surface reflectance 11 1614 0.959
# Interpolating tiles
# Wrote rhos_1614 (2941, 3050)
# S2A_MSI/B11 took 3.8s (RevLUT)
# Wrote rhot_2202 (2941, 3050)
# Computing surface reflectance 12 2202 0.913
# Interpolating tiles
# Wrote rhos_2202 (2941, 3050)
# S2A_MSI/B12 took 3.8s (RevLUT)
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R.nc
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_sza.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_vza.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_raa.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_443.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_443.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_492.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_492.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_560.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_560.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_665.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_665.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_704.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_704.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_740.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_740.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_783.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_783.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_833.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_833.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_865.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_865.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_945.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_1373.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_1614.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_1614.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhot_2202.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rhos_2202.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rgb_rhot.png
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R_rgb_rhos.png
# Deleting /kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L1R.nc
# Generated output files {0: {'input': '/kaggle/input/litter-windrows-batch-cala/S2A_MSIL1C_20181007T094031_N0500_R036_T33SXC_20230727T233522/S2A_MSIL1C_20181007T094031_N0500_R036_T33SXC_20230727T233522.SAFE', 'l1r': ['/kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L1R.nc'], 'l2r': ['/kaggle/working/acolite_output//S2A_MSI_2018_10_07_09_49_58_T33SXC_L2R.nc']}}
# stacking bands
# Stacked GeoTIFF saved to: /kaggle/working/stacked/S2_20181007T094031_N0500_stacked.tiff
# Stacked GeoTIFF:
# Bounds: BoundingBox(left=600000.0, bottom=4270610.0, right=630500.0, top=4300020.0)
# Dimensions: 3050 columns, 2941 rows
# Resolution: (10.0, 10.0)
# CRS: EPSG:32633
# Number of bands: 11
# Band descriptions: ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12')
# Percentage of invalid values (NaN, Inf, negative) across all bands: 0.07%
# patch dir /kaggle/working/patches/S2_20181007T094031_N0500
# cropping  patch (512, 8192, 768, 8448, 170)
# patch pathname /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_605120_4272140.tiff
# Cropped GeoTIFF saved to: /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_605120_4272140.tiff
# Cropped GeoTIFF:
# Bounds: BoundingBox(left=605120.0, bottom=4272140.0, right=607680.0, top=4274700.0)
# Dimensions: 256 columns, 256 rows
# Resolution: (10.0, 10.0)
# CRS: EPSG:32633
# Number of bands: 11
# Band descriptions: ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12')
# patch mask shape (256, 256)
# cropping  patch (512, 8704, 768, 8960, 9)
# patch pathname /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_605120_4277260.tiff
# Cropped GeoTIFF saved to: /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_605120_4277260.tiff
# Cropped GeoTIFF:
# Bounds: BoundingBox(left=605120.0, bottom=4277260.0, right=607680.0, top=4279820.0)
# Dimensions: 256 columns, 256 rows
# Resolution: (10.0, 10.0)
# CRS: EPSG:32633
# Number of bands: 11
# Band descriptions: ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12')
# patch mask shape (256, 256)
# cropping  patch (512, 8960, 768, 9216, 32)
# patch pathname /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_605120_4279820.tiff
# Cropped GeoTIFF saved to: /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_605120_4279820.tiff
# Cropped GeoTIFF:
# Bounds: BoundingBox(left=605120.0, bottom=4279820.0, right=607680.0, top=4282380.0)
# Dimensions: 256 columns, 256 rows
# Resolution: (10.0, 10.0)
# CRS: EPSG:32633
# Number of bands: 11
# Band descriptions: ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12')
# patch mask shape (256, 256)
# cropping  patch (256, 9216, 512, 9472, 59)
# patch pathname /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_602560_4282380.tiff
# Cropped GeoTIFF saved to: /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_602560_4282380.tiff
# Cropped GeoTIFF:
# Bounds: BoundingBox(left=602560.0, bottom=4282380.0, right=605120.0, top=4284940.0)
# Dimensions: 256 columns, 256 rows
# Resolution: (10.0, 10.0)
# CRS: EPSG:32633
# Number of bands: 11
# Band descriptions: ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12')
# patch mask shape (256, 256)
# cropping  patch (512, 9216, 768, 9472, 62)
# patch pathname /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_605120_4282380.tiff
# Cropped GeoTIFF saved to: /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_605120_4282380.tiff
# Cropped GeoTIFF:
# Bounds: BoundingBox(left=605120.0, bottom=4282380.0, right=607680.0, top=4284940.0)
# Dimensions: 256 columns, 256 rows
# Resolution: (10.0, 10.0)
# CRS: EPSG:32633
# Number of bands: 11
# Band descriptions: ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12')
# patch mask shape (256, 256)
# cropping  patch (0, 9728, 256, 9984, 127)
# patch pathname /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_600000_4287500.tiff
# Cropped GeoTIFF saved to: /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_600000_4287500.tiff
# Cropped GeoTIFF:
# Bounds: BoundingBox(left=600000.0, bottom=4287500.0, right=602560.0, top=4290060.0)
# Dimensions: 256 columns, 256 rows
# Resolution: (10.0, 10.0)
# CRS: EPSG:32633
# Number of bands: 11
# Band descriptions: ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12')
# patch mask shape (256, 256)
# cropping  patch (256, 9728, 512, 9984, 15)
# patch pathname /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_602560_4287500.tiff
# Cropped GeoTIFF saved to: /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_602560_4287500.tiff
# Cropped GeoTIFF:
# Bounds: BoundingBox(left=602560.0, bottom=4287500.0, right=605120.0, top=4290060.0)
# Dimensions: 256 columns, 256 rows
# Resolution: (10.0, 10.0)
# CRS: EPSG:32633
# Number of bands: 11
# Band descriptions: ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12')
# patch mask shape (256, 256)
# cropping  patch (0, 9984, 256, 10240, 15)
# patch pathname /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_600000_4290060.tiff
# Cropped GeoTIFF saved to: /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_600000_4290060.tiff
# Cropped GeoTIFF:
# Bounds: BoundingBox(left=600000.0, bottom=4290060.0, right=602560.0, top=4292620.0)
# Dimensions: 256 columns, 256 rows
# Resolution: (10.0, 10.0)
# CRS: EPSG:32633
# Number of bands: 11
# Band descriptions: ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12')
# patch mask shape (256, 256)
# cropping  patch (256, 9984, 512, 10240, 63)
# patch pathname /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_602560_4290060.tiff
# Cropped GeoTIFF saved to: /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_602560_4290060.tiff
# Cropped GeoTIFF:
# Bounds: BoundingBox(left=602560.0, bottom=4290060.0, right=605120.0, top=4292620.0)
# Dimensions: 256 columns, 256 rows
# Resolution: (10.0, 10.0)
# CRS: EPSG:32633
# Number of bands: 11
# Band descriptions: ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12')
# patch mask shape (256, 256)
# cropping  patch (0, 10240, 256, 10496, 41)
# patch pathname /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_600000_4292620.tiff
# Cropped GeoTIFF saved to: /kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_600000_4292620.tiff
# Cropped GeoTIFF:
# Bounds: BoundingBox(left=600000.0, bottom=4292620.0, right=602560.0, top=4295180.0)
# Dimensions: 256 columns, 256 rows
# Resolution: (10.0, 10.0)
# CRS: EPSG:32633
# Number of bands: 11
# Band descriptions: ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12')
# patch mask shape (256, 256)
#
# Disk usage after run:
# 5.7G	/kaggle/input/litter-windrows-batch-cala
# 68M	/kaggle/input/lw-parquet
# df: /kaggle/tmp: No such file or directory
# Filesystem      Size  Used Avail Use% Mounted on
# /dev/loop1       20G  3.6G   16G  19% /kaggle/working

# %%
upload_to_dagshub('/kaggle/working', '/kaggle/working/patches', './LWC_DataSet/test_data', "", dagshub_token=dagshub_token)
# Out:
# uploading files ['/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_630720_4243980.tiff', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_605120_4272140.tiff', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_640960_4215820._cl.tif', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_646080_4228620._cl.tif', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_602560_4290060._cl.tif', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_664000_4228620._cl.tif', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_605120_4272140._cl.tif', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_635840_4218380.tiff', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_643520_4228620.tiff', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_605120_4282380._cl.tif', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_635840_4218380._cl.tif', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_661440_4231180._cl.tif', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_646080_4226060.tiff', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_635840_4220940.tiff', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_635840_4241420.tiff', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_635840_4226060._cl.tif', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_635840_4238860._cl.tif', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_638400_4220940._cl.tif', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_656320_4233740.tiff', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_653760_4228620._cl.tif', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_635840_4238860.tiff', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_646080_4226060._cl.tif', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_656320_4231180._cl.tif', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_653760_4233740.tiff', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_640960_4228620.tiff', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_648640_4233740.tiff', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_664000_4231180._cl.tif', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_605120_4277260._cl.tif', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_661440_4231180.tiff', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_638400_4215820._cl.tif', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_656320_4231180.tiff', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_664000_4231180.tiff', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_638400_4226060.tiff', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_630720_4243980._cl.tif', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_638400_4226060._cl.tif', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_646080_4228620.tiff', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_684480_4195340._cl.tif', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_656320_4233740._cl.tif', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_600000_4290060.tiff', '/kaggle/working/patches/S2_20181007T094031_N0500/S2_20181007T094031_N0500_658880_4231180.tiff', '/kaggle/working/patches/S2_20181007T094 ...
# relative files ['S2_20181007T094031_N0500/S2_20181007T094031_N0500_630720_4243980.tiff', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_605120_4272140.tiff', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_640960_4215820._cl.tif', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_646080_4228620._cl.tif', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_602560_4290060._cl.tif', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_664000_4228620._cl.tif', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_605120_4272140._cl.tif', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_635840_4218380.tiff', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_643520_4228620.tiff', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_605120_4282380._cl.tif', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_635840_4218380._cl.tif', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_661440_4231180._cl.tif', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_646080_4226060.tiff', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_635840_4220940.tiff', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_635840_4241420.tiff', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_635840_4226060._cl.tif', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_635840_4238860._cl.tif', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_638400_4220940._cl.tif', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_656320_4233740.tiff', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_653760_4228620._cl.tif', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_635840_4238860.tiff', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_646080_4226060._cl.tif', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_656320_4231180._cl.tif', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_653760_4233740.tiff', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_640960_4228620.tiff', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_648640_4233740.tiff', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_664000_4231180._cl.tif', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_605120_4277260._cl.tif', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_661440_4231180.tiff', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_638400_4215820._cl.tif', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_656320_4231180.tiff', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_664000_4231180.tiff', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_638400_4226060.tiff', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_630720_4243980._cl.tif', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_638400_4226060._cl.tif', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_646080_4228620.tiff', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_684480_4195340._cl.tif', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_656320_4233740._cl.tif', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_600000_4290060.tiff', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_658880_4231180.tiff', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_600000_4292620._cl.tif', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_600000_4292620.tiff', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_640960_4210700._cl.tif', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_687040_4192780._cl.tif', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_640960_4208140.tiff', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_653760_4233740._cl.tif', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_633280_4241420._cl.tif', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_635840_4223500.tiff', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_643520_4215820.tiff', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_638400_4220940.tiff', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_605120_4279820._cl.tif', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_651200_4233740.tiff', 'S2_20181007T094031_N0500/S2_20181007T094031_N0500_643520_4228620._cl.tif', 'S2_20181007T094031_N0500/S2_20 ...
# Uploading files (104) to "elena-andreini/TriesteItalyChapter_PlasticDebrisDetection"...
# Upload finished successfully!
# Uploaded batch

# %%
! mv  ./patches/S2_20181017T094011_N0500/S2_20181017T094011_N0500_610240_4264460.tiff ./patches/S2_20181017T094011_N0500/S2_20181017T094011_N0500_610240_4264460.tif

# %%
process_batch([tiles[5]],safe_files_dir, annotations_files,  batch_id='', dagshub_token=dagshub_token)
# Out:
# building annotations dataframe for tile S2A_MSIL1C_20181017T094011_N0500_R036_T33SXC_20230729T163213.SAFE
# Batch 1: 0 rows (from 10 files)
# Batch 2: 0 rows (from 10 files)
# Batch 3: 0 rows (from 10 files)
# Batch 4: 0 rows (from 10 files)
# Batch 5: 30756 rows (from 10 files)
# Batch 6: 0 rows (from 10 files)
# Batch 7: 0 rows (from 10 files)
# Batch 8: 0 rows (from 10 files)
# Batch 9: 0 rows (from 10 files)
# Batch 10: 0 rows (from 10 files)
# Batch 11: 0 rows (from 10 files)
# Batch 12: 0 rows (from 10 files)
# Batch 13: 0 rows (from 10 files)
# Batch 14: 0 rows (from 10 files)
# Batch 15: 0 rows (from 8 files)
# 30756it [00:01, 20934.31it/s]
# tile mask shape (10980, 10980)
# input maks shape : (10980, 10980)
# patches with marine debris : [(1024, 7424, 1280, 7680, 42), (512, 9984, 768, 10240, 11), (512, 10240, 768, 10496, 19)]
# /kaggle/input/litter-windrows-batch-cala/S2A_MSIL1C_20181017T094011_N0500_R036_T33SXC_20230729T163213/S2A_MSIL1C_20181017T094011_N0500_R036_T33SXC_20230729T163213.SAFE/GRANULE/L1C_T33SXC_A017336_20181017T094338/IMG_DATA/T33SXC_20181017T094011_B02.jp2
# CRS: EPSG:32633
# Bounds: BoundingBox(left=600000.0, bottom=4190220.0, right=709800.0, top=4300020.0)
# B02 Valid Pixels: 120560400 / 120560400
# crs : EPSG:32633
# bounds : BoundingBox(left=600000.0, bottom=4190220.0, right=709800.0, top=4300020.0)
# No invalid pixels found in the bounding box
# No invalid pixels found in the bounding box
# No invalid pixels found in the bounding box
# No invalid pixels found in the bounding box
# No invalid pixels found in the bounding box
# No invalid pixels found in the bounding box
# No invalid pixels found in the bounding box
# No invalid pixels found in the bounding box
# No invalid pixels found in the bounding box
# No invalid pixels found in the bounding box
# No invalid pixels found in the bounding box
# No invalid pixels found in the bounding box
# No invalid pixels found in the bounding box
# No invalid pixels found in the bounding box
# No invalid pixels found in the bounding box
# No invalid pixels found in the bounding box
# patches per region {2: [(1024, 7424, 1280, 7680, 42)], 3: [(512, 9984, 768, 10240, 11), (512, 10240, 768, 10496, 19)]}
# region center : (615000.0, 4259220.0)
# Disk usage before run:
# 5.7G	/kaggle/input/litter-windrows-batch-cala
# 68M	/kaggle/input/lw-parquet
# df: /kaggle/tmp: No such file or directory
# Filesystem      Size  Used Avail Use% Mounted on
# /dev/loop1       20G  735M   19G   4% /kaggle/working
# Cleaning previous acolite output
#
# Processing subregion 3/16 centered at UTM (615000.0, 4259220.0)
# UTM box: left=600000.0, bottom=4244220.0, right=630000.0, top=4274220.0
# WGS84 limit: [38.340546901902016, 16.144280997385355, 38.60696898970145, 16.493035025540543]
# setting limit : [38.340546901902016, 16.144280997385355, 38.60696898970145, 16.493035025540543]
# Settings for subregion 3: {'l2r_export_geotiff': True, 'l1r_delete_netcdf': True, 'l2w_delete_netcdf': True, 'verbosity': 5, 's2_target_res': 10, 'resampling_method': 'nearest', 'atmospheric_correction_method': 'dark_spectrum', 'dsf_exclude_bands': ['B9', 'B10'], 'geometry_type': 'grids', 'l2w_mask': False, 'glint_correction': True, 'dsf_residual_glint_correction': True, 'dsf_residual_glint_correction_method': 'alternative', 'dsf_residual_glint_wave_range': [1500, 2400], 'glint_force_band': None, 'glint_mask_rhos_wave': 1600, 'glint_mask_rhos_threshold': 0.11, 'reproject': False, 'limit': [38.340546901902016, 16.144280997385355, 38.60696898970145, 16.493035025540543]}
# Running ACOLITE processing - Generic GitHub Clone c2025-04-23T15:27:02
# Python - linux - 3.11.11 (main, Dec  4 2024, 08:55:07) [GCC 11.4.0]
# Platform - Linux 6.6.56+ - x86_64 - #1 SMP PREEMPT_DYNAMIC Sun Nov 10 10:07:59 UTC 2024
# Run ID - 20250423_153546
# Identified /kaggle/input/litter-windrows-batch-cala/S2A_MSIL1C_20181017T094011_N0500_R036_T33SXC_20230729T163213/S2A_MSIL1C_20181017T094011_N0500_R036_T33SXC_20230729T163213.SAFE as Sentinel-2 type
# Starting conversion of 1 scenes
# Starting conversion of /kaggle/input/litter-windrows-batch-cala/S2A_MSIL1C_20181017T094011_N0500_R036_T33SXC_20230729T163213/S2A_MSIL1C_20181017T094011_N0500_R036_T33SXC_20230729T163213.SAFE
# Importing metadata from L1C_T33SXC_A017336_20181017T094338
# Reading per pixel geometry
# Wrote raa (3000, 3049)
# Wrote vza (3000, 3049)
# Wrote sza (3000, 3049)
# Writing geolocation lon/lat
# Wrote lon (3000, 3049)
# Wrote lat (3000, 3049)
# Converting bands
# Converting bands: Wrote rhot_443 ((3000, 3049))
# Converting bands: Wrote rhot_492 ((3000, 3049))
# Converting bands: Wrote rhot_560 ((3000, 3049))
# Converting bands: Wrote rhot_665 ((3000, 3049))
# Converting bands: Wrote rhot_704 ((3000, 3049))
# Converting bands: Wrote rhot_740 ((3000, 3049))
# Converting bands: Wrote rhot_783 ((3000, 3049))
# Converting bands: Wrote rhot_833 ((3000, 3049))
# Converting bands: Wrote rhot_865 ((3000, 3049))
# Converting bands: Wrote rhot_945 ((3000, 3049))
# Converting bands: Wrote rhot_1373 ((3000, 3049))
# Converting bands: Wrote rhot_1614 ((3000, 3049))
# Converting bands: Wrote rhot_2202 ((3000, 3049))
# Conversion took 24.8 seconds
# Created /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L1R.nc
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L1R_rgb_rhot.png
# Running acolite for /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L1R.nc
# Getting ancillary data for 2018-10-17T09:49:59.095443+00:00 16.321E 38.474N
# Downloading file GMAO_MERRA2.20181017T090000.MET.nc
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/GMAO_MERRA2.20181017T090000.MET.nc
# Finished downloading file GMAO_MERRA2.20181017T090000.MET.nc
# Downloading file GMAO_MERRA2.20181017T100000.MET.nc
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/GMAO_MERRA2.20181017T100000.MET.nc
# Finished downloading file GMAO_MERRA2.20181017T100000.MET.nc
# No ozone file found for 2018-10-17T09:49:59.095443+00:00
# No NCEP files found for 2018-10-17T09:49:59.095443+00:00
# default uoz: 0.30 uwv: 1.50 pressure: 1013.25
# current uoz: 0.30 uwv: 1.50 pressure: 1013.25
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/Gas/Gas_202106F.nc
# Testing LUT /kaggle/working/acolite/data/LUT/Gas/Gas_202106F.nc
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/WV/WV_201710C.nc
# Testing LUT /kaggle/working/acolite/data/LUT/WV/WV_201710C.nc
# Using DSF atmospheric correction
# Processing with 30 tiles (5x6 tiles of 600x600 pixels)
# Writing lon
# Wrote lon (3000, 3049)
# Writing lat
# Wrote lat (3000, 3049)
# Writing sza
# Wrote sza (3000, 3049)
# Writing vza
# Wrote vza (3000, 3049)
# Writing raa
# Wrote raa (3000, 3049)
# Loading LUTs ['ACOLITE-LUT-202110-MOD1', 'ACOLITE-LUT-202110-MOD2']
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD1-reverse-S2A_MSI-romix-1.nc
# Testing LUT /kaggle/working/acolite/data/LUT/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD1-reverse-S2A_MSI-romix-1.nc
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD1-reverse-S2A_MSI-romix-2.nc
# Testing LUT /kaggle/working/acolite/data/LUT/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD1-reverse-S2A_MSI-romix-2.nc
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD1-reverse-S2A_MSI-romix-3.nc
# Testing LUT /kaggle/working/acolite/data/LUT/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD1-reverse-S2A_MSI-romix-3.nc
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD1-reverse-S2A_MSI-romix-4.nc
# Testing LUT /kaggle/working/acolite/data/LUT/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD1-reverse-S2A_MSI-romix-4.nc
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD1-reverse-S2A_MSI-romix-5.nc
# Testing LUT /kaggle/working/acolite/data/LUT/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD1-reverse-S2A_MSI-romix-5.nc
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD1-reverse-S2A_MSI-romix-6.nc
# Testing LUT /kaggle/working/acolite/data/LUT/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD1-reverse-S2A_MSI-romix-6.nc
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD1-reverse-S2A_MSI-romix-7.nc
# Testing LUT /kaggle/working/acolite/data/LUT/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD1-reverse-S2A_MSI-romix-7.nc
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD1-reverse-S2A_MSI-romix-8.nc
# Testing LUT /kaggle/working/acolite/data/LUT/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD1-reverse-S2A_MSI-romix-8.nc
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD1-reverse-S2A_MSI-romix-8A.nc
# Testing LUT /kaggle/working/acolite/data/LUT/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD1-reverse-S2A_MSI-romix-8A.nc
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD1-reverse-S2A_MSI-romix-9.nc
# Testing LUT /kaggle/working/acolite/data/LUT/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD1-reverse-S2A_MSI-romix-9.nc
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD1-reverse-S2A_MSI-romix-10.nc
# Testing LUT /kaggle/working/acolite/data/LUT/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD1-reverse-S2A_MSI-romix-10.nc
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD1-reverse-S2A_MSI-romix-11.nc
# Testing LUT /kaggle/working/acolite/data/LUT/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD1-reverse-S2A_MSI-romix-11.nc
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD1-reverse-S2A_MSI-romix-12.nc
# Testing LUT /kaggle/working/acolite/data/LUT/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD1-reverse-S2A_MSI-romix-12.nc
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD2-reverse-S2A_MSI-romix-1.nc
# Testing LUT /kaggle/working/acolite/data/LUT/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD2-reverse-S2A_MSI-romix-1.nc
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD2-reverse-S2A_MSI-romix-2.nc
# Testing LUT /kaggle/working/acolite/data/LUT/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD2-reverse-S2A_MSI-romix-2.nc
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD2-reverse-S2A_MSI-romix-3.nc
# Testing LUT /kaggle/working/acolite/data/LUT/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD2-reverse-S2A_MSI-romix-3.nc
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD2-reverse-S2A_MSI-romix-4.nc
# Testing LUT /kaggle/working/acolite/data/LUT/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD2-reverse-S2A_MSI-romix-4.nc
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD2-reverse-S2A_MSI-romix-5.nc
# Testing LUT /kaggle/working/acolite/data/LUT/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD2-reverse-S2A_MSI-romix-5.nc
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD2-reverse-S2A_MSI-romix-6.nc
# Testing LUT /kaggle/working/acolite/data/LUT/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD2-reverse-S2A_MSI-romix-6.nc
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD2-reverse-S2A_MSI-romix-7.nc
# Testing LUT /kaggle/working/acolite/data/LUT/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD2-reverse-S2A_MSI-romix-7.nc
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD2-reverse-S2A_MSI-romix-8.nc
# Testing LUT /kaggle/working/acolite/data/LUT/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD2-reverse-S2A_MSI-romix-8.nc
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD2-reverse-S2A_MSI-romix-8A.nc
# Testing LUT /kaggle/working/acolite/data/LUT/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD2-reverse-S2A_MSI-romix-8A.nc
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD2-reverse-S2A_MSI-romix-9.nc
# Testing LUT /kaggle/working/acolite/data/LUT/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD2-reverse-S2A_MSI-romix-9.nc
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD2-reverse-S2A_MSI-romix-10.nc
# Testing LUT /kaggle/working/acolite/data/LUT/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD2-reverse-S2A_MSI-romix-10.nc
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD2-reverse-S2A_MSI-romix-11.nc
# Testing LUT /kaggle/working/acolite/data/LUT/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD2-reverse-S2A_MSI-romix-11.nc
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD2-reverse-S2A_MSI-romix-12.nc
# Testing LUT /kaggle/working/acolite/data/LUT/ACOLITE-LUT-202110-Reverse/S2A_MSI/ACOLITE-LUT-202110-MOD2-reverse-S2A_MSI-romix-12.nc
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/ACOLITE-LUT-202110/S2A_MSI/ACOLITE-LUT-202110-MOD1-0500mb_S2A_MSI.nc
# Testing LUT /kaggle/working/acolite/data/LUT/ACOLITE-LUT-202110/S2A_MSI/ACOLITE-LUT-202110-MOD1-0500mb_S2A_MSI.nc
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/ACOLITE-LUT-202110/S2A_MSI/ACOLITE-LUT-202110-MOD1-0750mb_S2A_MSI.nc
# Testing LUT /kaggle/working/acolite/data/LUT/ACOLITE-LUT-202110/S2A_MSI/ACOLITE-LUT-202110-MOD1-0750mb_S2A_MSI.nc
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/ACOLITE-LUT-202110/S2A_MSI/ACOLITE-LUT-202110-MOD1-1013mb_S2A_MSI.nc
# Testing LUT /kaggle/working/acolite/data/LUT/ACOLITE-LUT-202110/S2A_MSI/ACOLITE-LUT-202110-MOD1-1013mb_S2A_MSI.nc
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/ACOLITE-LUT-202110/S2A_MSI/ACOLITE-LUT-202110-MOD1-1100mb_S2A_MSI.nc
# Testing LUT /kaggle/working/acolite/data/LUT/ACOLITE-LUT-202110/S2A_MSI/ACOLITE-LUT-202110-MOD1-1100mb_S2A_MSI.nc
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/ACOLITE-LUT-202110/S2A_MSI/ACOLITE-LUT-202110-MOD2-0500mb_S2A_MSI.nc
# Testing LUT /kaggle/working/acolite/data/LUT/ACOLITE-LUT-202110/S2A_MSI/ACOLITE-LUT-202110-MOD2-0500mb_S2A_MSI.nc
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/ACOLITE-LUT-202110/S2A_MSI/ACOLITE-LUT-202110-MOD2-0750mb_S2A_MSI.nc
# Testing LUT /kaggle/working/acolite/data/LUT/ACOLITE-LUT-202110/S2A_MSI/ACOLITE-LUT-202110-MOD2-0750mb_S2A_MSI.nc
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/ACOLITE-LUT-202110/S2A_MSI/ACOLITE-LUT-202110-MOD2-1013mb_S2A_MSI.nc
# Testing LUT /kaggle/working/acolite/data/LUT/ACOLITE-LUT-202110/S2A_MSI/ACOLITE-LUT-202110-MOD2-1013mb_S2A_MSI.nc
# Getting remote LUT https://raw.githubusercontent.com/acolite/acolite_luts/main/ACOLITE-LUT-202110/S2A_MSI/ACOLITE-LUT-202110-MOD2-1100mb_S2A_MSI.nc
# Testing LUT /kaggle/working/acolite/data/LUT/ACOLITE-LUT-202110/S2A_MSI/ACOLITE-LUT-202110-MOD2-1100mb_S2A_MSI.nc
# Loading LUTs took 69.7 s
# Running AOT estimation for band 1 (rhot_443)
# S2A_MSI/B1 ACOLITE-LUT-202110-MOD1 took 0.002s (RevLUT)
# S2A_MSI/B1 ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Running AOT estimation for band 2 (rhot_492)
# S2A_MSI/B2 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B2 ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Running AOT estimation for band 3 (rhot_560)
# S2A_MSI/B3 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B3 ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Running AOT estimation for band 4 (rhot_665)
# S2A_MSI/B4 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B4 ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Running AOT estimation for band 5 (rhot_704)
# S2A_MSI/B5 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B5 ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Running AOT estimation for band 6 (rhot_740)
# S2A_MSI/B6 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B6 ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Running AOT estimation for band 7 (rhot_783)
# S2A_MSI/B7 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B7 ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Running AOT estimation for band 8 (rhot_833)
# S2A_MSI/B8 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B8 ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Running AOT estimation for band 8A (rhot_865)
# S2A_MSI/B8A ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B8A ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Choosing best fitting model: min_drmsd (2 bands)
# Computing RMSD for model ACOLITE-LUT-202110-MOD1
# Computing RMSD for model ACOLITE-LUT-202110-MOD2
# Selecting most common model for processing.
# ACOLITE-LUT-202110-MOD1: 56.0%: mean aot of subset = 0.67
# ACOLITE-LUT-202110-MOD2: 44.0%: mean aot of subset = 0.85
# Selected ACOLITE-LUT-202110-MOD1, mean aot = 0.73
# use_revlut True
# Wrote rhot_443 (3000, 3049)
# Computing surface reflectance 1 443 0.998
# Interpolating tiles
# /kaggle/working/./acolite/acolite/acolite/acolite_l2r.py:1001: RuntimeWarning: Mean of empty slice
#   cur_sel_par = np.sqrt(np.nanmean(np.square((rhod_f-rhop_f)), axis=2))
# Wrote rhos_443 (3000, 3049)
# S2A_MSI/B1 took 3.8s (RevLUT)
# Wrote rhot_492 (3000, 3049)
# Computing surface reflectance 2 492 0.980
# Interpolating tiles
# Wrote rhos_492 (3000, 3049)
# S2A_MSI/B2 took 3.8s (RevLUT)
# Wrote rhot_560 (3000, 3049)
# Computing surface reflectance 3 560 0.921
# Interpolating tiles
# Wrote rhos_560 (3000, 3049)
# S2A_MSI/B3 took 3.8s (RevLUT)
# Wrote rhot_665 (3000, 3049)
# Computing surface reflectance 4 665 0.953
# Interpolating tiles
# Wrote rhos_665 (3000, 3049)
# S2A_MSI/B4 took 3.7s (RevLUT)
# Wrote rhot_704 (3000, 3049)
# Computing surface reflectance 5 704 0.946
# Interpolating tiles
# Wrote rhos_704 (3000, 3049)
# S2A_MSI/B5 took 3.8s (RevLUT)
# Wrote rhot_740 (3000, 3049)
# Computing surface reflectance 6 740 0.956
# Interpolating tiles
# Wrote rhos_740 (3000, 3049)
# S2A_MSI/B6 took 3.7s (RevLUT)
# Wrote rhot_783 (3000, 3049)
# Computing surface reflectance 7 783 0.983
# Interpolating tiles
# Wrote rhos_783 (3000, 3049)
# S2A_MSI/B7 took 3.7s (RevLUT)
# Wrote rhot_833 (3000, 3049)
# Computing surface reflectance 8 833 0.936
# Interpolating tiles
# Wrote rhos_833 (3000, 3049)
# S2A_MSI/B8 took 3.7s (RevLUT)
# Wrote rhot_865 (3000, 3049)
# Computing surface reflectance 8A 865 0.997
# Interpolating tiles
# Wrote rhos_865 (3000, 3049)
# S2A_MSI/B8A took 3.8s (RevLUT)
# Wrote rhot_945 (3000, 3049)
# Band 9 at 945 nm has tgas < min_tgas_rho (0.27 < 0.70)
# Wrote rhot_1373 (3000, 3049)
# Band 10 at 1373 nm has tgas < min_tgas_rho (0.01 < 0.70)
# Wrote rhot_1614 (3000, 3049)
# Computing surface reflectance 11 1614 0.958
# Interpolating tiles
# Wrote rhos_1614 (3000, 3049)
# S2A_MSI/B11 took 3.8s (RevLUT)
# Wrote rhot_2202 (3000, 3049)
# Computing surface reflectance 12 2202 0.910
# Interpolating tiles
# Wrote rhos_2202 (3000, 3049)
# S2A_MSI/B12 took 3.8s (RevLUT)
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R.nc
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_sza.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_vza.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_raa.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhot_443.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhos_443.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhot_492.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhos_492.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhot_560.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhos_560.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhot_665.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhos_665.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhot_704.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhos_704.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhot_740.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhos_740.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhot_783.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhos_783.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhot_833.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhos_833.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhot_865.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhos_865.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhot_945.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhot_1373.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhot_1614.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhos_1614.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhot_2202.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhos_2202.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rgb_rhot.png
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rgb_rhos.png
# Deleting /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L1R.nc
# Generated output files {0: {'input': '/kaggle/input/litter-windrows-batch-cala/S2A_MSIL1C_20181017T094011_N0500_R036_T33SXC_20230729T163213/S2A_MSIL1C_20181017T094011_N0500_R036_T33SXC_20230729T163213.SAFE', 'l1r': ['/kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L1R.nc'], 'l2r': ['/kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R.nc']}}
# stacking bands
# Stacked GeoTIFF saved to: /kaggle/working/stacked/S2_20181017T094011_N0500_stacked.tiff
# Stacked GeoTIFF:
# Bounds: BoundingBox(left=600000.0, bottom=4244210.0, right=630490.0, top=4274210.0)
# Dimensions: 3049 columns, 3000 rows
# Resolution: (10.0, 10.0)
# CRS: EPSG:32633
# Number of bands: 11
# Band descriptions: ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12')
# Percentage of invalid values (NaN, Inf, negative) across all bands: 0.13%
# patch dir /kaggle/working/patches/S2_20181017T094011_N0500
# cropping  patch (1024, 7424, 1280, 7680, 42)
# patch pathname /kaggle/working/patches/S2_20181017T094011_N0500/S2_20181017T094011_N0500_610240_4264460.tiff
# Cropped GeoTIFF saved to: /kaggle/working/patches/S2_20181017T094011_N0500/S2_20181017T094011_N0500_610240_4264460.tiff
# Cropped GeoTIFF:
# Bounds: BoundingBox(left=610240.0, bottom=4264460.0, right=612800.0, top=4267020.0)
# Dimensions: 256 columns, 256 rows
# Resolution: (10.0, 10.0)
# CRS: EPSG:32633
# Number of bands: 11
# Band descriptions: ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12')
# patch mask shape (256, 256)
# Accessing as elena-andreini
# uploading files ['/kaggle/working/patches/S2_20181017T094011_N0500/S2_20181017T094011_N0500_610240_4264460.tiff', '/kaggle/working/patches/S2_20181017T094011_N0500/S2_20181017T094011_N0500_610240_4264460._cl.tif']
# relative files ['S2_20181017T094011_N0500/S2_20181017T094011_N0500_610240_4264460.tiff', 'S2_20181017T094011_N0500/S2_20181017T094011_N0500_610240_4264460._cl.tif']
# Uploading files (2) to "elena-andreini/TriesteItalyChapter_PlasticDebrisDetection"...
# Exception captured: Versioning requested 'dvc' impossible for file '' - versioned with 'git'
# region center : (615000.0, 4285620.0)
# Disk usage before run:
# 5.7G	/kaggle/input/litter-windrows-batch-cala
# 68M	/kaggle/input/lw-parquet
# df: /kaggle/tmp: No such file or directory
# Filesystem      Size  Used Avail Use% Mounted on
# /dev/loop1       20G  3.1G   17G  16% /kaggle/working
# Cleaning previous acolite output
#
# Processing subregion 4/16 centered at UTM (615000.0, 4285620.0)
# UTM box: left=600000.0, bottom=4270620.0, right=630000.0, top=4300620.0
# WGS84 limit: [38.57842106579689, 16.148045554427263, 38.84479877654529, 16.497993783541283]
# setting limit : [38.57842106579689, 16.148045554427263, 38.84479877654529, 16.497993783541283]
# Settings for subregion 4: {'l2r_export_geotiff': True, 'l1r_delete_netcdf': True, 'l2w_delete_netcdf': True, 'verbosity': 5, 's2_target_res': 10, 'resampling_method': 'nearest', 'atmospheric_correction_method': 'dark_spectrum', 'dsf_exclude_bands': ['B9', 'B10'], 'geometry_type': 'grids', 'l2w_mask': False, 'glint_correction': True, 'dsf_residual_glint_correction': True, 'dsf_residual_glint_correction_method': 'alternative', 'dsf_residual_glint_wave_range': [1500, 2400], 'glint_force_band': None, 'glint_mask_rhos_wave': 1600, 'glint_mask_rhos_threshold': 0.11, 'reproject': False, 'limit': [38.57842106579689, 16.148045554427263, 38.84479877654529, 16.497993783541283]}
# Running ACOLITE processing - Generic GitHub Clone c2025-04-23T15:27:02
# Python - linux - 3.11.11 (main, Dec  4 2024, 08:55:07) [GCC 11.4.0]
# Platform - Linux 6.6.56+ - x86_64 - #1 SMP PREEMPT_DYNAMIC Sun Nov 10 10:07:59 UTC 2024
# Run ID - 20250423_153844
# Identified /kaggle/input/litter-windrows-batch-cala/S2A_MSIL1C_20181017T094011_N0500_R036_T33SXC_20230729T163213/S2A_MSIL1C_20181017T094011_N0500_R036_T33SXC_20230729T163213.SAFE as Sentinel-2 type
# Starting conversion of 1 scenes
# Starting conversion of /kaggle/input/litter-windrows-batch-cala/S2A_MSIL1C_20181017T094011_N0500_R036_T33SXC_20230729T163213/S2A_MSIL1C_20181017T094011_N0500_R036_T33SXC_20230729T163213.SAFE
# Importing metadata from L1C_T33SXC_A017336_20181017T094338
# Reading per pixel geometry
# Wrote raa (2941, 3050)
# Wrote vza (2941, 3050)
# Wrote sza (2941, 3050)
# Writing geolocation lon/lat
# Wrote lon (2941, 3050)
# Wrote lat (2941, 3050)
# Converting bands
# Converting bands: Wrote rhot_443 ((2941, 3050))
# Converting bands: Wrote rhot_492 ((2941, 3050))
# Converting bands: Wrote rhot_560 ((2941, 3050))
# Converting bands: Wrote rhot_665 ((2941, 3050))
# Converting bands: Wrote rhot_704 ((2941, 3050))
# Converting bands: Wrote rhot_740 ((2941, 3050))
# Converting bands: Wrote rhot_783 ((2941, 3050))
# Converting bands: Wrote rhot_833 ((2941, 3050))
# Converting bands: Wrote rhot_865 ((2941, 3050))
# Converting bands: Wrote rhot_945 ((2941, 3050))
# Converting bands: Wrote rhot_1373 ((2941, 3050))
# Converting bands: Wrote rhot_1614 ((2941, 3050))
# Converting bands: Wrote rhot_2202 ((2941, 3050))
# Conversion took 19.3 seconds
# Created /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L1R.nc
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L1R_rgb_rhot.png
# Running acolite for /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L1R.nc
# Getting ancillary data for 2018-10-17T09:49:59.095443+00:00 16.326E 38.709N
# Downloading file GMAO_MERRA2.20181017T090000.MET.nc
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/GMAO_MERRA2.20181017T090000.MET.nc
# Finished downloading file GMAO_MERRA2.20181017T090000.MET.nc
# Downloading file GMAO_MERRA2.20181017T100000.MET.nc
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/GMAO_MERRA2.20181017T100000.MET.nc
# Finished downloading file GMAO_MERRA2.20181017T100000.MET.nc
# No ozone file found for 2018-10-17T09:49:59.095443+00:00
# No NCEP files found for 2018-10-17T09:49:59.095443+00:00
# default uoz: 0.30 uwv: 1.50 pressure: 1013.25
# current uoz: 0.30 uwv: 1.50 pressure: 1013.25
# Using DSF atmospheric correction
# Processing with 30 tiles (5x6 tiles of 600x600 pixels)
# Writing lon
# Wrote lon (2941, 3050)
# Writing lat
# Wrote lat (2941, 3050)
# Writing sza
# Wrote sza (2941, 3050)
# Writing vza
# Wrote vza (2941, 3050)
# Writing raa
# Wrote raa (2941, 3050)
# Loading LUTs ['ACOLITE-LUT-202110-MOD1', 'ACOLITE-LUT-202110-MOD2']
# Loading LUTs took 2.3 s
# Running AOT estimation for band 1 (rhot_443)
# S2A_MSI/B1 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B1 ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Running AOT estimation for band 2 (rhot_492)
# S2A_MSI/B2 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B2 ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Running AOT estimation for band 3 (rhot_560)
# S2A_MSI/B3 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B3 ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Running AOT estimation for band 4 (rhot_665)
# S2A_MSI/B4 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B4 ACOLITE-LUT-202110-MOD2 took 0.002s (RevLUT)
# Running AOT estimation for band 5 (rhot_704)
# S2A_MSI/B5 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B5 ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Running AOT estimation for band 6 (rhot_740)
# S2A_MSI/B6 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B6 ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Running AOT estimation for band 7 (rhot_783)
# S2A_MSI/B7 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B7 ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Running AOT estimation for band 8 (rhot_833)
# S2A_MSI/B8 ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B8 ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Running AOT estimation for band 8A (rhot_865)
# S2A_MSI/B8A ACOLITE-LUT-202110-MOD1 took 0.001s (RevLUT)
# S2A_MSI/B8A ACOLITE-LUT-202110-MOD2 took 0.001s (RevLUT)
# Choosing best fitting model: min_drmsd (2 bands)
# Computing RMSD for model ACOLITE-LUT-202110-MOD1
# Computing RMSD for model ACOLITE-LUT-202110-MOD2
# Selecting most common model for processing.
# ACOLITE-LUT-202110-MOD1: 36.7%: mean aot of subset = 0.61
# ACOLITE-LUT-202110-MOD2: 63.3%: mean aot of subset = 0.64
# Selected ACOLITE-LUT-202110-MOD2, mean aot = 0.63
# use_revlut True
# Wrote rhot_443 (2941, 3050)
# Computing surface reflectance 1 443 0.998
# Interpolating tiles
# Wrote rhos_443 (2941, 3050)
# S2A_MSI/B1 took 3.8s (RevLUT)
# Wrote rhot_492 (2941, 3050)
# Computing surface reflectance 2 492 0.980
# Interpolating tiles
# Wrote rhos_492 (2941, 3050)
# S2A_MSI/B2 took 3.7s (RevLUT)
# Wrote rhot_560 (2941, 3050)
# Computing surface reflectance 3 560 0.920
# Interpolating tiles
# Wrote rhos_560 (2941, 3050)
# S2A_MSI/B3 took 3.7s (RevLUT)
# Wrote rhot_665 (2941, 3050)
# Computing surface reflectance 4 665 0.953
# Interpolating tiles
# Wrote rhos_665 (2941, 3050)
# S2A_MSI/B4 took 3.6s (RevLUT)
# Wrote rhot_704 (2941, 3050)
# Computing surface reflectance 5 704 0.946
# Interpolating tiles
# Wrote rhos_704 (2941, 3050)
# S2A_MSI/B5 took 3.8s (RevLUT)
# Wrote rhot_740 (2941, 3050)
# Computing surface reflectance 6 740 0.956
# Interpolating tiles
# Wrote rhos_740 (2941, 3050)
# S2A_MSI/B6 took 3.7s (RevLUT)
# Wrote rhot_783 (2941, 3050)
# Computing surface reflectance 7 783 0.983
# Interpolating tiles
# Wrote rhos_783 (2941, 3050)
# S2A_MSI/B7 took 3.7s (RevLUT)
# Wrote rhot_833 (2941, 3050)
# Computing surface reflectance 8 833 0.936
# Interpolating tiles
# Wrote rhos_833 (2941, 3050)
# S2A_MSI/B8 took 3.7s (RevLUT)
# Wrote rhot_865 (2941, 3050)
# Computing surface reflectance 8A 865 0.997
# Interpolating tiles
# Wrote rhos_865 (2941, 3050)
# S2A_MSI/B8A took 3.6s (RevLUT)
# Wrote rhot_945 (2941, 3050)
# Band 9 at 945 nm has tgas < min_tgas_rho (0.27 < 0.70)
# Wrote rhot_1373 (2941, 3050)
# Band 10 at 1373 nm has tgas < min_tgas_rho (0.01 < 0.70)
# Wrote rhot_1614 (2941, 3050)
# Computing surface reflectance 11 1614 0.958
# Interpolating tiles
# Wrote rhos_1614 (2941, 3050)
# S2A_MSI/B11 took 3.7s (RevLUT)
# Wrote rhot_2202 (2941, 3050)
# Computing surface reflectance 12 2202 0.910
# Interpolating tiles
# Wrote rhos_2202 (2941, 3050)
# S2A_MSI/B12 took 3.7s (RevLUT)
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R.nc
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_sza.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_vza.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_raa.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhot_443.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhos_443.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhot_492.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhos_492.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhot_560.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhos_560.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhot_665.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhos_665.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhot_704.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhos_704.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhot_740.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhos_740.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhot_783.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhos_783.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhot_833.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhos_833.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhot_865.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhos_865.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhot_945.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhot_1373.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhot_1614.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhos_1614.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhot_2202.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rhos_2202.tif
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rgb_rhot.png
# Wrote /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R_rgb_rhos.png
# Deleting /kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L1R.nc
# Generated output files {0: {'input': '/kaggle/input/litter-windrows-batch-cala/S2A_MSIL1C_20181017T094011_N0500_R036_T33SXC_20230729T163213/S2A_MSIL1C_20181017T094011_N0500_R036_T33SXC_20230729T163213.SAFE', 'l1r': ['/kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L1R.nc'], 'l2r': ['/kaggle/working/acolite_output//S2A_MSI_2018_10_17_09_49_59_T33SXC_L2R.nc']}}
# stacking bands
# Stacked GeoTIFF saved to: /kaggle/working/stacked/S2_20181017T094011_N0500_stacked.tiff
# Stacked GeoTIFF:
# Bounds: BoundingBox(left=600000.0, bottom=4270610.0, right=630500.0, top=4300020.0)
# Dimensions: 3050 columns, 2941 rows
# Resolution: (10.0, 10.0)
# CRS: EPSG:32633
# Number of bands: 11
# Band descriptions: ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12')
# Percentage of invalid values (NaN, Inf, negative) across all bands: 0.34%
# patch dir /kaggle/working/patches/S2_20181017T094011_N0500
# cropping  patch (512, 9984, 768, 10240, 11)
# patch pathname /kaggle/working/patches/S2_20181017T094011_N0500/S2_20181017T094011_N0500_605120_4290060.tiff
# Cropped GeoTIFF saved to: /kaggle/working/patches/S2_20181017T094011_N0500/S2_20181017T094011_N0500_605120_4290060.tiff
# Cropped GeoTIFF:
# Bounds: BoundingBox(left=605120.0, bottom=4290060.0, right=607680.0, top=4292620.0)
# Dimensions: 256 columns, 256 rows
# Resolution: (10.0, 10.0)
# CRS: EPSG:32633
# Number of bands: 11
# Band descriptions: ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12')
# patch mask shape (256, 256)
# cropping  patch (512, 10240, 768, 10496, 19)
# patch pathname /kaggle/working/patches/S2_20181017T094011_N0500/S2_20181017T094011_N0500_605120_4292620.tiff
# Cropped GeoTIFF saved to: /kaggle/working/patches/S2_20181017T094011_N0500/S2_20181017T094011_N0500_605120_4292620.tiff
# Cropped GeoTIFF:
# Bounds: BoundingBox(left=605120.0, bottom=4292620.0, right=607680.0, top=4295180.0)
# Dimensions: 256 columns, 256 rows
# Resolution: (10.0, 10.0)
# CRS: EPSG:32633
# Number of bands: 11
# Band descriptions: ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12')
# patch mask shape (256, 256)
# uploading files ['/kaggle/working/patches/S2_20181017T094011_N0500/S2_20181017T094011_N0500_610240_4264460.tiff', '/kaggle/working/patches/S2_20181017T094011_N0500/S2_20181017T094011_N0500_605120_4290060.tiff', '/kaggle/working/patches/S2_20181017T094011_N0500/S2_20181017T094011_N0500_605120_4292620._cl.tif', '/kaggle/working/patches/S2_20181017T094011_N0500/S2_20181017T094011_N0500_605120_4292620.tiff', '/kaggle/working/patches/S2_20181017T094011_N0500/S2_20181017T094011_N0500_605120_4290060._cl.tif', '/kaggle/working/patches/S2_20181017T094011_N0500/S2_20181017T094011_N0500_610240_4264460._cl.tif']
# relative files ['S2_20181017T094011_N0500/S2_20181017T094011_N0500_610240_4264460.tiff', 'S2_20181017T094011_N0500/S2_20181017T094011_N0500_605120_4290060.tiff', 'S2_20181017T094011_N0500/S2_20181017T094011_N0500_605120_4292620._cl.tif', 'S2_20181017T094011_N0500/S2_20181017T094011_N0500_605120_4292620.tiff', 'S2_20181017T094011_N0500/S2_20181017T094011_N0500_605120_4290060._cl.tif', 'S2_20181017T094011_N0500/S2_20181017T094011_N0500_610240_4264460._cl.tif']
# Uploading files (6) to "elena-andreini/TriesteItalyChapter_PlasticDebrisDetection"...
# Exception captured: Versioning requested 'dvc' impossible for file '' - versioned with 'git'

# %%
process_tile(tiles[7], safe_files_dir, annotations_files, '/kaggle/working', batch_id)

# %%
! ls /kaggle/working/patches/S2_20181017T094011_N0500

# %%
import os.path

def get_relative_path(target_path, start_path):
    """
    Returns the relative path from start_path to target_path
    """
    return os.path.relpath(target_path, start_path)

# Example usage:
relative_path = get_relative_path("/full/path/to/file", "/full/path")
print(relative_path)  # Output: to/file
# Out:
# to/file

# %%
! ls
# Out:
# patches  pathces

# %%
! mkdir ./patches
! mkdir ./patches/S2_patch1

# %%
import numpy as np
import cv2

im = np.random.rand(256, 256)
mask = np.random.rand(256, 256)
cv2.imwrite('./patches/S2_patch1/image.png', im)
cv2.imwrite('./patches/S2_patch1/mask.png', mask)
# Out:
# [ WARN:0@60.350] global loadsave.cpp:848 imwrite_ Unsupported depth image for selected encoder is fallbacked to CV_8U.
# True

# %%
! dagshub login
# Out:
#                                 ❗❗❗ AUTHORIZATION REQUIRED ❗❗❗
#
#
# Open the following link in your browser to authorize the client:
# https://dagshub.com/login/oauth/authorize?state=69e713dd-1d6e-452d-a459-f27f5078b9e8&client_id=32b60ba385aa7cecf24046d8195a71c07dd345d9657977863b52e7748e0f0f28&middleman_request_id=8f666fdc97a5062e8106984d8a5e242569e1e33705b304b232ec7411fdb0dc05
#
#
# ⠧ Waiting for authorizationon2025-04-23 09:30:25,793 - [INFO]  - [_client.py:1025] - HTTP Request: POST https://dagshub.com/login/oauth/middleman "HTTP/1.1 200 OK"
# ⠧ Waiting for authorization
# 2025-04-23 09:30:25,911 - [INFO]  - [_client.py:1025] - HTTP Request: POST https://dagshub.com/login/oauth/access_token "HTTP/1.1 200 OK"
# ✅ OAuth token added

# %%
get_all_files_recursive('/kaggle/working/patches')
# Out:
# ['/kaggle/working/patches/S2_patch1/mask.png',
#  '/kaggle/working/patches/S2_patch1/image.png']

# %%
! ls ./kaggle/working/patches
# Out:
# ls: cannot access './kaggle/working/patches': No such file or directory

# %%
upload_to_dagshub('/kaggle/working', '/kaggle/working/patches', './test_data/patches', 'batch0')
# Out:
# uploading files ['/kaggle/working/patches/S2_patch1/mask.png', '/kaggle/working/patches/S2_patch1/image.png']
# relative files ['S2_patch1/mask.png', 'S2_patch1/image.png']
# Uploading files (2) to "elena-andreini/TriesteItalyChapter_PlasticDebrisDetection"...
# ---------------------------------------------------------------------------
# DagsHubAPIError                           Traceback (most recent call last)
# /tmp/ipykernel_31/3898785031.py in <cell line: 0>()
# ----> 1 upload_to_dagshub('/kaggle/working', '/kaggle/working/patches', './test_data/patches', 'batch0')
#
# /tmp/ipykernel_31/4028159348.py in upload_to_dagshub(root_folder, src_folder, dst_folder, batch_id)
#      39
#      40     # Commit the changes
# ---> 41     ds.commit(f'Adding batch {batch_id}  to {dst_folder} folder', versioning='dvc')
#      42     print(f'Uploaded batch {batch_id}')
#
# /usr/local/lib/python3.11/dist-packages/dagshub/upload/wrapper.py in commit(self, commit_message, *args, **kwargs)
#     848
#     849         file_list = list(self.files.values())
# --> 850         self.repo.upload_files(file_list, self.directory, commit_message=commit_message, *args, **kwargs)
#     851         self._reset_dataset()
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in wrapped_f(*args, **kw)
#     334             copy = self.copy()
#     335             wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 336             return copy(f, *args, **kw)
#     337
#     338         def retry_with(*args: t.Any, **kwargs: t.Any) -> WrappedFn:
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     473         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474         while True:
# --> 475             do = self.iter(retry_state=retry_state)
#     476             if isinstance(do, DoAttempt):
#     477                 try:
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in iter(self, retry_state)
#     374         result = None
#     375         for action in self.iter_state.actions:
# --> 376             result = action(retry_state)
#     377         return result
#     378
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in <lambda>(rs)
#     396     def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     397         if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 398             self._add_action_func(lambda rs: rs.outcome.result())
#     399             return
#     400
#
# /usr/lib/python3.11/concurrent/futures/_base.py in result(self, timeout)
#     447                     raise CancelledError()
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#     451                 self._condition.wait(timeout)
#
# /usr/lib/python3.11/concurrent/futures/_base.py in __get_result(self)
#     399         if self._exception:
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#     403                 # Break a reference cycle with the exception in self._exception
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     476             if isinstance(do, DoAttempt):
#     477                 try:
# --> 478                     result = fn(*args, **kwargs)
#     479                 except BaseException:  # noqa: B902
#     480                     retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# /usr/local/lib/python3.11/dist-packages/dagshub/upload/wrapper.py in upload_files(self, files, directory_path, commit_message, versioning, new_branch, last_commit, force, quiet)
#     425             timeout=None,
#     426         )
# --> 427         self._log_upload_details(data, res, files, quiet)
#     428
#     429         # The ETag header contains the hash of the uploaded commit,
#
# /usr/local/lib/python3.11/dist-packages/dagshub/upload/wrapper.py in _log_upload_details(self, data, res, files, quiet)
#     465             log_message(f"Got unknown successful status code {res.status_code}")
#     466         else:
# --> 467             raise determine_upload_api_error(res)
#     468
#     469     def _poll_mirror_up_to_date(self):
#
# DagsHubAPIError: file missing from storage:
# Required resource is missing from the storage, is 'test_data/patches' stored in your repository DagsHub storage?

# %%
from dagshub.upload import Repo
import os



def get_relative_path(target_path, start_path):
    """
    Returns the relative path from start_path to target_path
    """
    return os.path.relpath(target_path, start_path)


def get_all_files_recursive(directory):
    file_paths = []
    for root, dirs, files in os.walk(directory):
        #print(files)
        for file in files:
            full_path = os.path.abspath(os.path.join(root, file))
            if os.path.isfile(full_path):  # Check to ensure it's a file
                file_paths.append(full_path)
    return file_paths

def upload_to_dagshub(root_folder, src_folder, dst_folder, batch_id):
    """
    dst_folder: Must have the format './dest_folder',
    where dst_folder is the destination folder for the images
    relative to the root of the repository.
    
    root_folder: The relative path of src_folder with respect to root_folder
    will determine the position of the uploaded file relative to the root
    of the repository.
    """

    # Defining the Repo & directory
    repo = Repo("elena-andreini", "TriesteItalyChapter_PlasticDebrisDetection")
    ds = repo.directory(dst_folder)
    files = get_all_files_recursive(src_folder)
    print(f'uploading files {files}')
    rel_files_paths = [get_relative_path(f, src_folder) for f in files]
    print(f'relative files {rel_files_paths}')

    for i in rel_files_paths:
      ds.add(file=os.path.join(src_folder, i), path=f'./{i}')
    
    # Commit the changes
    ds.commit(f'Adding batch {batch_id}  to {dst_folder} folder', versioning='dvc')
    print(f'Uploaded batch {batch_id}')
